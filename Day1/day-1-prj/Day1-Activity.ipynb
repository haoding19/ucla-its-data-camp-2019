# %% [markdown]
# # UCLA ITS Data Camp, Day 1
# ## Retrieving Data via API Calls

# %% [markdown]
# An increasingly common way to retrieve data is via an application programming interface (API), which refers to a framework of communication between you (client) and some server (computer) somewhere else in the world ([here](https://medium.com/@perrysetgo/what-exactly-is-an-api-69f36968a41f) for a high-level overview). You don't need to know how to program to make a basic API call; in fact, you are making API calls every day as you browse the internet and request webpages from the servers that host the web content. The most common way we make an API call is using the HTTP protocol (which you can see in any URL) and abiding by the [REST design principles](https://en.wikipedia.org/wiki/Representational_state_transfer).
#
# Beyond serving webpages, HTTP REST APIs have become an increasingly popular method for exchanging data across the internet, especially for cases where the data is granular and is being refreshed constantly. When you are consuming data via a REST API, there are four main types of actions you can perform:
#
# GET: For reading/obtaining a resource from the server. This is the most common action and is the one we will be making for all of our calls since we will be _consuming_ data in this course.
#
# POST: For creating a resource on the server
#
# PUT: For updating a resource on the server
#
# DELETE: For deleting a resource on the server
#
# ### Exercise 1: Accessing Open Data Portal APIs
#
# ##### Notebook Setup
# As you did with the Pre-Course exercise, create a new project directory with the structure below and place this workbook within it.
# ```
# day-1-prj/
# ├── data/
# ├── output/
# └── Day_1.ipynb
# ```
# ##### Setting up an API call
# For today's lesson, we will be learning how to make REST API calls within Python, using the `requests` package, which you can read more about [here](https://2.python-requests.org/en/master/). If the package is not yet installed on your machine, make sure you do so. Data from an API is typically delivered as [XML or JSON](https://github.com/black-tea/ucla-its-data-camp-2019/blob/master/Pre-Course/Programming-Landscape.md#some-common-data-formats).
#
# In the last lesson we loaded data by reading in a CSV file. Today we are going to download the same set of data via an API call and ingesting the JSON-formatted response.

# %%
# Creating directories
import os

path = 'data/processed'

try:
    os.mkdir(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)
# Out:
# Successfully created the directory data/processed

# %%
# Import packages
import requests

# Store the url in a variable
url = 'https://opendata.arcgis.com/datasets/bed43aa2945a47b18ae888246712ccb1_0.geojson'

# TODO: Make the request & store in a variable
resp = requests.get(url)

# %% [markdown]
# The response object includes a lot of different information. For example, we can get the status of the request (successful or unsuccessful) by calling `resp.status_code`. You will enounter several different [response codes](https://www.restapitutorial.com/httpstatuscodes.html) when working with APIs.

# %%
# TODO: Print the status code
resp.status_code
# Out:
# 200

# %% [markdown]
# If the response was successful (`200`), we want to take a look at the output. For JSON-formatted data, we can access the body of the response by calling `resp.json()`. Let's take a look at the JSON output of our response.

# %%
# Examine the response content
resp.json()
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'OBJECTID': 4001,
#     'CASE_ID': '4127182',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-08-22T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-29T00:00:00.000Z',
#     'COLLISION_TIME': 1215,
#     'OFFICER_ID': '39053',
#     'REPORTING_DISTRICT': '1232',
#     'DAY_OF_WEEK': '4',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'L',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '12T44',
#     'PRIMARY_RD': 'SLAUSON AV',
#     'SECONDARY_RD': '3RD AV',
#     'DISTANCE': 0,
#     'DIRECTION': None,
#     'INTERSECTION': 'Y',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'N',
#     'COLLISION_SEVERITY': '4',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 1,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '04',
#     'PCF_VIOLATION': 21703,
#     'PCF_VIOL_SUBSECTION': None,
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': 'C',
#     'MVIW': 'C',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'A',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': 'A',
#     'CHP_VEHTYPE_AT_FAULT': '01',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 1,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 1500,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.320580000054,
#     'POINT_Y': 33.989070892334,
#     'Match_addr': 'W SLAUSON AVE & 3RD AVE, LOS ANGELES, CA, 90043',
#     'm_primaryrd': 'W SLAUSON AVE',
#     'm_secondrd': '3RD AVE'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.32057999999995, 33.98907089200003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4002,
#     'CASE_ID': '4127195',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-08-25T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-23T00:00:00.000Z',
#     'COLLISION_TIME': 1320,
#     'OFFICER_ID': '37506',
#     'REPORTING_DISTRICT': '0182',
#     'DAY_OF_WEEK': '5',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'A',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '13TL53',
#     'PRIMARY_RD': 'FLOWER ST',
#     'SECONDARY_RD': 'OLYMPIC BL',
#     'DISTANCE': 79,
#     'DIRECTION': 'S',
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'B',
#     'WEATHER_2': 'C',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'Y',
#     'COLLISION_SEVERITY': '4',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 1,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '08',
#     'PCF_VIOLATION': 22100,
#     'PCF_VIOL_SUBSECTION': 'B',
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': 'C',
#     'MVIW': 'C',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'B',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'A',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': 'A',
#     'CHP_VEHTYPE_AT_FAULT': '01',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 1,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 1500,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.262935324678,
#     'POINT_Y': 34.0442390441895,
#     'Match_addr': 'S FLOWER ST & W OLYMPIC BLVD, LOS ANGELES, CA, 90015',
#     'm_primaryrd': 'S FLOWER ST',
#     'm_secondrd': 'W OLYMPIC BLVD'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.26293532499994, 34.04423904400005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4003,
#     'CASE_ID': '4127211',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-09-08T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-17T00:00:00.000Z',
#     'COLLISION_TIME': 1250,
#     'OFFICER_ID': '37506',
#     'REPORTING_DISTRICT': '1183',
#     'DAY_OF_WEEK': '6',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'K',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '11TL25',
#     'PRIMARY_RD': 'ECHO PARK AV',
#     'SECONDARY_RD': 'EFFIE ST',
#     'DISTANCE': 42,
#     'DIRECTION': 'S',
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'Y',
#     'COLLISION_SEVERITY': '0',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 0,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '03',
#     'PCF_VIOLATION': 22350,
#     'PCF_VIOL_SUBSECTION': None,
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': 'C',
#     'MVIW': 'C',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'A',
#     'CONTROL_DEVICE': 'A',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': 'D',
#     'CHP_VEHTYPE_AT_FAULT': '22',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 1500,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.254033573903,
#     'POINT_Y': 34.0840911865234,
#     'Match_addr': 'ECHO PARK AVE & EFFIE ST, LOS ANGELES, CA, 90026',
#     'm_primaryrd': 'ECHO PARK AVE',
#     'm_secondrd': 'EFFIE ST'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.25403357399995, 34.08409118700007]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4004,
#     'CASE_ID': '4127215',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-09-09T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-27T00:00:00.000Z',
#     'COLLISION_TIME': 305,
#     'OFFICER_ID': '36814',
#     'REPORTING_DISTRICT': '0428',
#     'DAY_OF_WEEK': '2',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'D',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '1T11',
#     'PRIMARY_RD': 'PHELPS AV',
#     'SECONDARY_RD': 'LYNNFIELD ST',
#     'DISTANCE': 200,
#     'DIRECTION': 'S',
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'Y',
#     'COLLISION_SEVERITY': '0',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 0,
#     'PARTY_COUNT': 1,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '03',
#     'PCF_VIOLATION': 22350,
#     'PCF_VIOL_SUBSECTION': None,
#     'HIT_AND_RUN': 'M',
#     'TYPE_OF_COLLISION': 'E',
#     'MVIW': 'I',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'C',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': 'A',
#     'CHP_VEHTYPE_AT_FAULT': '01',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 600,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.177198123145,
#     'POINT_Y': 34.0796699523926,
#     'Match_addr': 'PHELPS AVE & LYNNFIELD ST, LOS ANGELES, CA, 90032',
#     'm_primaryrd': 'PHELPS AVE',
#     'm_secondrd': 'LYNNFIELD ST'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.17719812299998, 34.079669952000074]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4005,
#     'CASE_ID': '4127220',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-09-08T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-30T00:00:00.000Z',
#     'COLLISION_TIME': 1400,
#     'OFFICER_ID': '39163',
#     'REPORTING_DISTRICT': '0152',
#     'DAY_OF_WEEK': '5',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'A',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '1A41',
#     'PRIMARY_RD': '6TH ST',
#     'SECONDARY_RD': 'FLOWER ST',
#     'DISTANCE': 0,
#     'DIRECTION': None,
#     'INTERSECTION': 'Y',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'N',
#     'COLLISION_SEVERITY': '4',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 1,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '10',
#     'PCF_VIOLATION': 21950,
#     'PCF_VIOL_SUBSECTION': 'A',
#     'HIT_AND_RUN': 'F',
#     'TYPE_OF_COLLISION': 'G',
#     'MVIW': 'B',
#     'PED_ACTION': 'B',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'A',
#     'CONTROL_DEVICE': 'A',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': 'Y',
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': '-',
#     'CHP_VEHTYPE_AT_FAULT': '99',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 1,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 1,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 1500,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.257479999884,
#     'POINT_Y': 34.0501594543457,
#     'Match_addr': 'W 6TH ST & S FLOWER ST, LOS ANGELES, CA, 90017',
#     'm_primaryrd': 'W 6TH ST',
#     'm_secondrd': 'S FLOWER ST'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.25747999999999, 34.05015945400004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4006,
#     'CASE_ID': '4127224',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-09-08T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-24T00:00:00.000Z',
#     'COLLISION_TIME': 2030,
#     'OFFICER_ID': '33977',
#     'REPORTING_DISTRICT': '0152',
#     'DAY_OF_WEEK': '6',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'A',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '1T11',
#     'PRIMARY_RD': '6TH ST',
#     'SECONDARY_RD': 'HOPE ST',
#     'DISTANCE': 0,
#     'DIRECTION': None,
#     'INTERSECTION': 'Y',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'Y',
#     'COLLISION_SEVERITY': '3',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 3,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '09',
#     'PCF_VIOLATION': 21801,
#     'PCF_VIOL_SUBSECTION': 'A',
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': 'D',
#     'MVIW': 'C',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'C',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': 'A',
#     'CHP_VEHTYPE_AT_FAULT': '01',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 1,
#     'COUNT_COMPLAIN_PAIN': 2,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 2100,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.256349999627,
#     'POINT_Y': 34.0494918823242,
#     'Match_addr': 'W 6TH ST & S HOPE ST, LOS ANGELES, CA, 90017',
#     'm_primaryrd': 'W 6TH ST',
#     'm_secondrd': 'S HOPE ST'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.25634999999994, 34.04949188200004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4007,
#     'CASE_ID': '4127228',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-09-09T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-25T00:00:00.000Z',
#     'COLLISION_TIME': 1835,
#     'OFFICER_ID': '33977',
#     'REPORTING_DISTRICT': '1195',
#     'DAY_OF_WEEK': '7',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'K',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '1T11',
#     'PRIMARY_RD': 'STADIUM WY',
#     'SECONDARY_RD': 'CHAVEZ RAVINE PL',
#     'DISTANCE': 80,
#     'DIRECTION': 'E',
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'Y',
#     'COLLISION_SEVERITY': '3',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 1,
#     'PARTY_COUNT': 1,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '01',
#     'PCF_VIOLATION': 23152,
#     'PCF_VIOL_SUBSECTION': 'A',
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': '-',
#     'MVIW': 'I',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'C',
#     'CONTROL_DEVICE': '-',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': 'Y',
#     'STWD_VEHTYPE_AT_FAULT': 'A',
#     'CHP_VEHTYPE_AT_FAULT': '01',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 1,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 2100,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': 0,
#     'POINT_Y': 0,
#     'Match_addr': None,
#     'm_primaryrd': None,
#     'm_secondrd': None},
#    'geometry': {'type': 'Point',
#     'coordinates': [5.684341886080802e-14, 5.684341886080802e-14]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4008,
#     'CASE_ID': '4127232',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-09-08T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-30T00:00:00.000Z',
#     'COLLISION_TIME': 1937,
#     'OFFICER_ID': '33798',
#     'REPORTING_DISTRICT': '0101',
#     'DAY_OF_WEEK': '5',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'A',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '1T11',
#     'PRIMARY_RD': 'COLLEGE ST',
#     'SECONDARY_RD': 'BEAUDRY AV',
#     'DISTANCE': 16,
#     'DIRECTION': 'E',
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'N',
#     'COLLISION_SEVERITY': '0',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 0,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '21',
#     'PCF_VIOLATION': 22106,
#     'PCF_VIOL_SUBSECTION': None,
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': 'C',
#     'MVIW': 'C',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'C',
#     'CONTROL_DEVICE': 'A',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': 'A',
#     'CHP_VEHTYPE_AT_FAULT': '08',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 2100,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': 0,
#     'POINT_Y': 0,
#     'Match_addr': None,
#     'm_primaryrd': None,
#     'm_secondrd': None},
#    'geometry': {'type': 'Point',
#     'coordinates': [5.684341886080802e-14, 5.684341886080802e-14]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4009,
#     'CASE_ID': '4127235',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-09-08T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-30T00:00:00.000Z',
#     'COLLISION_TIME': 2330,
#     'OFFICER_ID': '38175',
#     'REPORTING_DISTRICT': '0257',
#     'DAY_OF_WEEK': '5',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'B',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '13T53',
#     'PRIMARY_RD': 'WITMER ST',
#     'SECONDARY_RD': 'WILSHIRE BL',
#     'DISTANCE': 100,
#     'DIRECTION': 'N',
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'B',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'Y',
#     'COLLISION_SEVERITY': '0',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 0,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '01',
#     'PCF_VIOLATION': 23152,
#     'PCF_VIOL_SUBSECTION': 'A',
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': 'C',
#     'MVIW': 'E',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'C',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': 'Y',
#     'STWD_VEHTYPE_AT_FAULT': 'A',
#     'CHP_VEHTYPE_AT_FAULT': '01',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 2400,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.266520722559,
#     'POINT_Y': 34.0540466308594,
#     'Match_addr': 'WITMER ST & WILSHIRE BLVD, LOS ANGELES, CA, 90017',
#     'm_primaryrd': 'WITMER ST',
#     'm_secondrd': 'WILSHIRE BLVD'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.26652072299999, 34.05404663100006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4010,
#     'CASE_ID': '4127239',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-09-08T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-13T00:00:00.000Z',
#     'COLLISION_TIME': 1400,
#     'OFFICER_ID': '37611',
#     'REPORTING_DISTRICT': '1128',
#     'DAY_OF_WEEK': '2',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'K',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '4TL4',
#     'PRIMARY_RD': 'AVENUE 64',
#     'SECONDARY_RD': 'CHURCH ST',
#     'DISTANCE': 45,
#     'DIRECTION': 'S',
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'Y',
#     'COLLISION_SEVERITY': '4',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 1,
#     'PARTY_COUNT': 3,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '03',
#     'PCF_VIOLATION': 22350,
#     'PCF_VIOL_SUBSECTION': None,
#     'HIT_AND_RUN': 'M',
#     'TYPE_OF_COLLISION': 'B',
#     'MVIW': 'E',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'A',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': 'D',
#     'CHP_VEHTYPE_AT_FAULT': '22',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 1,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 1500,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.176729630809,
#     'POINT_Y': 34.125072479248,
#     'Match_addr': 'AVE 64 & CHURCH ST, LOS ANGELES, CA, 90042',
#     'm_primaryrd': 'AVE 64',
#     'm_secondrd': 'CHURCH ST'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.17672963099994, 34.12507247900004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4011,
#     'CASE_ID': '4127243',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-10-09T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-29T00:00:00.000Z',
#     'COLLISION_TIME': 1547,
#     'OFFICER_ID': '38181',
#     'REPORTING_DISTRICT': '1101',
#     'DAY_OF_WEEK': '4',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'K',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '13TL22',
#     'PRIMARY_RD': 'CRYSTAL SPRINGS RD',
#     'SECONDARY_RD': 'GRIFFITH PARK DR',
#     'DISTANCE': 0,
#     'DIRECTION': None,
#     'INTERSECTION': 'Y',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'Y',
#     'COLLISION_SEVERITY': '3',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 3,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '01',
#     'PCF_VIOLATION': 23152,
#     'PCF_VIOL_SUBSECTION': 'A',
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': 'D',
#     'MVIW': 'C',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'A',
#     'CONTROL_DEVICE': 'A',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': 'Y',
#     'STWD_VEHTYPE_AT_FAULT': 'A',
#     'CHP_VEHTYPE_AT_FAULT': '01',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 3,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 1800,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.281940000207,
#     'POINT_Y': 34.1354484558105,
#     'Match_addr': 'CRYSTAL SPRINGS DR & GRIFFITH PARK DR, LOS ANGELES, CA, 90027',
#     'm_primaryrd': 'CRYSTAL SPRINGS DR',
#     'm_secondrd': 'GRIFFITH PARK DR'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.28193999999996, 34.13544845600006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4012,
#     'CASE_ID': '4127244',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-09-08T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-21T00:00:00.000Z',
#     'COLLISION_TIME': 855,
#     'OFFICER_ID': '36940',
#     'REPORTING_DISTRICT': '0158',
#     'DAY_OF_WEEK': '3',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'A',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '13TK55',
#     'PRIMARY_RD': '4TH ST',
#     'SECONDARY_RD': 'ALAMEDA ST',
#     'DISTANCE': 0,
#     'DIRECTION': None,
#     'INTERSECTION': 'Y',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'N',
#     'COLLISION_SEVERITY': '0',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 0,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '07',
#     'PCF_VIOLATION': 21658,
#     'PCF_VIOL_SUBSECTION': 'A',
#     'HIT_AND_RUN': 'M',
#     'TYPE_OF_COLLISION': 'B',
#     'MVIW': 'C',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'A',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': '-',
#     'CHP_VEHTYPE_AT_FAULT': '99',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 900,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.238130000304,
#     'POINT_Y': 34.043270111084,
#     'Match_addr': 'E 4TH ST & S ALAMEDA ST, LOS ANGELES, CA, 90013',
#     'm_primaryrd': 'E 4TH ST',
#     'm_secondrd': 'S ALAMEDA ST'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.23812999999996, 34.04327011100003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4013,
#     'CASE_ID': '4127247',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-10-06T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-26T00:00:00.000Z',
#     'COLLISION_TIME': 1330,
#     'OFFICER_ID': '38285',
#     'REPORTING_DISTRICT': '!0204',
#     'DAY_OF_WEEK': '1',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': None,
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '13TL55',
#     'PRIMARY_RD': 'SUNSET BL',
#     'SECONDARY_RD': 'GOLDEN GATE AV',
#     'DISTANCE': 0,
#     'DIRECTION': None,
#     'INTERSECTION': 'Y',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'Y',
#     'COLLISION_SEVERITY': '4',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 1,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '09',
#     'PCF_VIOLATION': 21801,
#     'PCF_VIOL_SUBSECTION': 'A',
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': 'D',
#     'MVIW': 'C',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'A',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': 'Y',
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': 'A',
#     'CHP_VEHTYPE_AT_FAULT': '08',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 1,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 1,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 1500,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.276389999787,
#     'POINT_Y': 34.0886497497559,
#     'Match_addr': 'W SUNSET BLVD & GOLDEN GATE AVE, LOS ANGELES, CA, 90026',
#     'm_primaryrd': 'W SUNSET BLVD',
#     'm_secondrd': 'GOLDEN GATE AVE'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.27638999999999, 34.08864975000006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4014,
#     'CASE_ID': '4127248',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-09-09T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-24T00:00:00.000Z',
#     'COLLISION_TIME': 750,
#     'OFFICER_ID': '38285',
#     'REPORTING_DISTRICT': '0192',
#     'DAY_OF_WEEK': '6',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'A',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '1TL11',
#     'PRIMARY_RD': 'WASHINGTON BL',
#     'SECONDARY_RD': 'OLIVE ST',
#     'DISTANCE': 20,
#     'DIRECTION': 'S',
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'C',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'Y',
#     'COLLISION_SEVERITY': '0',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 0,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '03',
#     'PCF_VIOLATION': 22350,
#     'PCF_VIOL_SUBSECTION': None,
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': 'C',
#     'MVIW': 'C',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'B',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'A',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': 'A',
#     'CHP_VEHTYPE_AT_FAULT': '01',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 900,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.267504714132,
#     'POINT_Y': 34.0323295593262,
#     'Match_addr': 'W WASHINGTON BLVD & S OLIVE ST, LOS ANGELES, CA, 90015',
#     'm_primaryrd': 'W WASHINGTON BLVD',
#     'm_secondrd': 'S OLIVE ST'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.26750471399998, 34.03232955900006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4015,
#     'CASE_ID': '4127251',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-09-08T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-24T00:00:00.000Z',
#     'COLLISION_TIME': 1830,
#     'OFFICER_ID': '33977',
#     'REPORTING_DISTRICT': '0439',
#     'DAY_OF_WEEK': '6',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'D',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '1T11',
#     'PRIMARY_RD': 'VALLEY BL',
#     'SECONDARY_RD': 'EASTERN AV',
#     'DISTANCE': 0,
#     'DIRECTION': None,
#     'INTERSECTION': 'Y',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'N',
#     'COLLISION_SEVERITY': '0',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 0,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '09',
#     'PCF_VIOLATION': 21801,
#     'PCF_VIOL_SUBSECTION': 'A',
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': 'A',
#     'MVIW': 'C',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'C',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': 'J',
#     'CHP_VEHTYPE_AT_FAULT': '48',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 2100,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.180260000527,
#     'POINT_Y': 34.0657615661621,
#     'Match_addr': 'VALLEY BLVD & N EASTERN AVE, LOS ANGELES, CA, 90032',
#     'm_primaryrd': 'VALLEY BLVD',
#     'm_secondrd': 'N EASTERN AVE'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.18026000099997, 34.06576156600005]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4016,
#     'CASE_ID': '4127252',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-09-08T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-21T00:00:00.000Z',
#     'COLLISION_TIME': 1335,
#     'OFFICER_ID': '37982',
#     'REPORTING_DISTRICT': '0135',
#     'DAY_OF_WEEK': '3',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'A',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '4T4',
#     'PRIMARY_RD': 'MAIN ST',
#     'SECONDARY_RD': '3RD ST',
#     'DISTANCE': 0,
#     'DIRECTION': 'N',
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'N',
#     'COLLISION_SEVERITY': '0',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 0,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '08',
#     'PCF_VIOLATION': 22100,
#     'PCF_VIOL_SUBSECTION': 'B',
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': 'D',
#     'MVIW': 'C',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'A',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': 'A',
#     'CHP_VEHTYPE_AT_FAULT': '01',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 1500,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.245869999642,
#     'POINT_Y': 34.0495300292969,
#     'Match_addr': 'S MAIN ST & E 3RD ST, LOS ANGELES, CA, 90012',
#     'm_primaryrd': 'S MAIN ST',
#     'm_secondrd': 'E 3RD ST'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.24586999999997, 34.04953002900004]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4017,
#     'CASE_ID': '4127255',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-09-08T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-31T00:00:00.000Z',
#     'COLLISION_TIME': 2320,
#     'OFFICER_ID': '38175',
#     'REPORTING_DISTRICT': '0271',
#     'DAY_OF_WEEK': '6',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'B',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '13T53',
#     'PRIMARY_RD': 'ALVARADO ST',
#     'SECONDARY_RD': 'OLYMPIC ST',
#     'DISTANCE': 85,
#     'DIRECTION': 'S',
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'N',
#     'COLLISION_SEVERITY': '0',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 0,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '03',
#     'PCF_VIOLATION': 22350,
#     'PCF_VIOL_SUBSECTION': None,
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': 'C',
#     'MVIW': 'E',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'C',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': 'A',
#     'CHP_VEHTYPE_AT_FAULT': '01',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 2400,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.279967132798,
#     'POINT_Y': 34.0515327453613,
#     'Match_addr': 'S ALVARADO ST & W OLYMPIC BLVD, LOS ANGELES, CA, 90006',
#     'm_primaryrd': 'S ALVARADO ST',
#     'm_secondrd': 'W OLYMPIC BLVD'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.27996713299996, 34.05153274500003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4018,
#     'CASE_ID': '4127256',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-09-08T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-26T00:00:00.000Z',
#     'COLLISION_TIME': 1830,
#     'OFFICER_ID': '37225',
#     'REPORTING_DISTRICT': '0162',
#     'DAY_OF_WEEK': '1',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'A',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '2TL28',
#     'PRIMARY_RD': 'FLOWER ST',
#     'SECONDARY_RD': '6TH ST',
#     'DISTANCE': 98,
#     'DIRECTION': 'S',
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'Y',
#     'COLLISION_SEVERITY': '0',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 0,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '03',
#     'PCF_VIOLATION': 22350,
#     'PCF_VIOL_SUBSECTION': None,
#     'HIT_AND_RUN': 'M',
#     'TYPE_OF_COLLISION': 'B',
#     'MVIW': 'E',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'C',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': 'A',
#     'CHP_VEHTYPE_AT_FAULT': '01',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 2100,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.25767736924,
#     'POINT_Y': 34.0499458312988,
#     'Match_addr': 'S FLOWER ST & W 6TH ST, LOS ANGELES, CA, 90017',
#     'm_primaryrd': 'S FLOWER ST',
#     'm_secondrd': 'W 6TH ST'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.25767736899996, 34.04994583100006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4019,
#     'CASE_ID': '4127259',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-09-08T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-22T00:00:00.000Z',
#     'COLLISION_TIME': 1320,
#     'OFFICER_ID': None,
#     'REPORTING_DISTRICT': '1162',
#     'DAY_OF_WEEK': '4',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'K',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '13TL53',
#     'PRIMARY_RD': 'VERMONT AV',
#     'SECONDARY_RD': 'LEXINGTON AV',
#     'DISTANCE': 0,
#     'DIRECTION': None,
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'Y',
#     'COLLISION_SEVERITY': '0',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 0,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '01',
#     'PCF_VIOLATION': 23152,
#     'PCF_VIOL_SUBSECTION': 'A',
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': 'C',
#     'MVIW': 'C',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'A',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': 'Y',
#     'STWD_VEHTYPE_AT_FAULT': 'D',
#     'CHP_VEHTYPE_AT_FAULT': '22',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 1500,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.291760000343,
#     'POINT_Y': 34.0934295654297,
#     'Match_addr': 'N VERMONT AVE & LEXINGTON AVE, LOS ANGELES, CA, 90029',
#     'm_primaryrd': 'N VERMONT AVE',
#     'm_secondrd': 'LEXINGTON AVE'},
#    'geometry': {'type': 'Point',
# ...
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 1,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 1,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 1800,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.198379999658,
#     'POINT_Y': 34.1068305969238,
#     'Match_addr': 'N FIGUEROA ST & S AVE 53, LOS ANGELES, CA, 90042',
#     'm_primaryrd': 'N FIGUEROA ST',
#     'm_secondrd': 'S AVE 53'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.19837999999999, 34.106830597000055]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4995,
#     'CASE_ID': '4136192',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-08-24T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-20T00:00:00.000Z',
#     'COLLISION_TIME': 1500,
#     'OFFICER_ID': '37611',
#     'REPORTING_DISTRICT': '1115',
#     'DAY_OF_WEEK': '2',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'K',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '11TL21',
#     'PRIMARY_RD': 'ALGOMA AV',
#     'SECONDARY_RD': 'YOSEMITE DR',
#     'DISTANCE': 0,
#     'DIRECTION': None,
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'N',
#     'COLLISION_SEVERITY': '0',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 0,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '21',
#     'PCF_VIOLATION': 22106,
#     'PCF_VIOL_SUBSECTION': None,
#     'HIT_AND_RUN': 'M',
#     'TYPE_OF_COLLISION': 'C',
#     'MVIW': 'E',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': '-',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'A',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': '-',
#     'CHP_VEHTYPE_AT_FAULT': '99',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 1800,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.205510000095,
#     'POINT_Y': 34.1332817077637,
#     'Match_addr': 'ALGOMA AVE & YOSEMITE DR, LOS ANGELES, CA, 90041',
#     'm_primaryrd': 'ALGOMA AVE',
#     'm_secondrd': 'YOSEMITE DR'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.20550999999995, 34.13328170800003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4996,
#     'CASE_ID': '4136196',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-08-24T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-28T00:00:00.000Z',
#     'COLLISION_TIME': 825,
#     'OFFICER_ID': '37218',
#     'REPORTING_DISTRICT': '1176',
#     'DAY_OF_WEEK': '3',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'K',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '11TL21',
#     'PRIMARY_RD': 'DORRIS PL',
#     'SECONDARY_RD': 'RIVERSIDE DR',
#     'DISTANCE': 165,
#     'DIRECTION': 'E',
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'N',
#     'COLLISION_SEVERITY': '0',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 0,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '08',
#     'PCF_VIOLATION': 22107,
#     'PCF_VIOL_SUBSECTION': None,
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': 'B',
#     'MVIW': 'E',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'A',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': 'D',
#     'CHP_VEHTYPE_AT_FAULT': '22',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 900,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.237843743233,
#     'POINT_Y': 34.0906791687012,
#     'Match_addr': 'DORRIS PL & RIVERSIDE DR, LOS ANGELES, CA, 90031',
#     'm_primaryrd': 'DORRIS PL',
#     'm_secondrd': 'RIVERSIDE DR'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.23784374299998, 34.090679169000055]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4997,
#     'CASE_ID': '4136200',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-08-24T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-30T00:00:00.000Z',
#     'COLLISION_TIME': 2110,
#     'OFFICER_ID': '37782',
#     'REPORTING_DISTRICT': '1139',
#     'DAY_OF_WEEK': '5',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'K',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '1T11',
#     'PRIMARY_RD': 'AVENUE 58',
#     'SECONDARY_RD': 'FIGUEROA ST',
#     'DISTANCE': 80,
#     'DIRECTION': 'E',
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'N',
#     'COLLISION_SEVERITY': '0',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 0,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '21',
#     'PCF_VIOLATION': 22106,
#     'PCF_VIOL_SUBSECTION': None,
#     'HIT_AND_RUN': 'M',
#     'TYPE_OF_COLLISION': 'C',
#     'MVIW': 'E',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'C',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': '-',
#     'CHP_VEHTYPE_AT_FAULT': '99',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 2400,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.191907711194,
#     'POINT_Y': 34.1097679138184,
#     'Match_addr': 'S AVE 58 & N FIGUEROA ST, LOS ANGELES, CA, 90042',
#     'm_primaryrd': 'S AVE 58',
#     'm_secondrd': 'N FIGUEROA ST'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.19190771099994, 34.10976791400003]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4998,
#     'CASE_ID': '4136204',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-08-24T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-11T00:00:00.000Z',
#     'COLLISION_TIME': 1850,
#     'OFFICER_ID': '39337',
#     'REPORTING_DISTRICT': '1151',
#     'DAY_OF_WEEK': '7',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'K',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': 'NOE',
#     'PRIMARY_RD': 'EDGEMONT ST',
#     'SECONDARY_RD': 'SUNSET BL',
#     'DISTANCE': 0,
#     'DIRECTION': None,
#     'INTERSECTION': 'Y',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'Y',
#     'COLLISION_SEVERITY': '4',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 1,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'D',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '00',
#     'PCF_VIOLATION': 0,
#     'PCF_VIOL_SUBSECTION': None,
#     'HIT_AND_RUN': 'F',
#     'TYPE_OF_COLLISION': 'D',
#     'MVIW': 'C',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'C',
#     'CONTROL_DEVICE': 'A',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': '-',
#     'CHP_VEHTYPE_AT_FAULT': '-',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 1,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 2100,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.296159999886,
#     'POINT_Y': 34.0981407165527,
#     'Match_addr': 'N EDGEMONT ST & W SUNSET BLVD, LOS ANGELES, CA, 90027',
#     'm_primaryrd': 'N EDGEMONT ST',
#     'm_secondrd': 'W SUNSET BLVD'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.29615999999999, 34.098140717000035]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 4999,
#     'CASE_ID': '4136208',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-08-24T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-17T00:00:00.000Z',
#     'COLLISION_TIME': 1010,
#     'OFFICER_ID': '37506',
#     'REPORTING_DISTRICT': '1172',
#     'DAY_OF_WEEK': '6',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'K',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '11TL25',
#     'PRIMARY_RD': 'ALVARADO ST',
#     'SECONDARY_RD': 'SCOTT AV',
#     'DISTANCE': 0,
#     'DIRECTION': None,
#     'INTERSECTION': 'Y',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'Y',
#     'COLLISION_SEVERITY': '4',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 1,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '09',
#     'PCF_VIOLATION': 21801,
#     'PCF_VIOL_SUBSECTION': 'A',
#     'HIT_AND_RUN': 'N',
#     'TYPE_OF_COLLISION': 'D',
#     'MVIW': 'C',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'A',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': 'A',
#     'CHP_VEHTYPE_AT_FAULT': '01',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 1,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 1200,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.260939999464,
#     'POINT_Y': 34.0817604064941,
#     'Match_addr': 'N ALVARADO ST & SCOTT AVE, LOS ANGELES, CA, 90026',
#     'm_primaryrd': 'N ALVARADO ST',
#     'm_secondrd': 'SCOTT AVE'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.26093999899996, 34.08176040600006]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 5000,
#     'CASE_ID': '4136241',
#     'ACCIDENT_YEAR': 2009,
#     'PROCDATE': '2009-08-22T00:00:00.000Z',
#     'JURIS': 1942,
#     'COLLISION_DATE': '2009-01-29T00:00:00.000Z',
#     'COLLISION_TIME': 1434,
#     'OFFICER_ID': '38181',
#     'REPORTING_DISTRICT': '1143',
#     'DAY_OF_WEEK': '4',
#     'SHIFT': '5',
#     'POPULATION': '7',
#     'CNTY_CITY_LOC': '1942',
#     'SPECIAL_COND': '0',
#     'BEAT_TYPE': '0',
#     'CHP_BEAT_TYPE': '0',
#     'CITY_DIVISION_LAPD': 'K',
#     'CHP_BEAT_CLASS': '0',
#     'BEATNUMB': '13TL22',
#     'PRIMARY_RD': 'HYPERION ST',
#     'SECONDARY_RD': 'UDELL CT',
#     'DISTANCE': 0,
#     'DIRECTION': None,
#     'INTERSECTION': 'N',
#     'WEATHER_1': 'A',
#     'WEATHER_2': '-',
#     'STATE_HWY_IND': 'N',
#     'CALTRANS_COUNTY': None,
#     'CALTRANS_DISTRICT': 0,
#     'STATE_ROUTE': 0,
#     'ROUTE_SUFFIX': None,
#     'POSTMILE_PREFIX': None,
#     'POSTMILE': 0,
#     'LOCATION_TYPE': None,
#     'RAMP_INTERSECTION': None,
#     'SIDE_OF_HWY': None,
#     'TOW_AWAY': 'N',
#     'COLLISION_SEVERITY': '0',
#     'NUMBER_KILLED': 0,
#     'NUMBER_INJURED': 0,
#     'PARTY_COUNT': 2,
#     'PRIMARY_COLL_FACTOR': 'A',
#     'PCF_CODE_VIOL': '-',
#     'PCF_VIOL_CATEGORY': '09',
#     'PCF_VIOLATION': 21801,
#     'PCF_VIOL_SUBSECTION': 'A',
#     'HIT_AND_RUN': 'M',
#     'TYPE_OF_COLLISION': 'B',
#     'MVIW': 'C',
#     'PED_ACTION': 'A',
#     'ROAD_SURFACE': 'A',
#     'ROAD_COND_1': 'H',
#     'ROAD_COND_2': '-',
#     'LIGHTING': 'A',
#     'CONTROL_DEVICE': 'D',
#     'CHP_ROAD_TYPE': '0',
#     'PEDESTRIAN_ACCIDENT': None,
#     'BICYCLE_ACCIDENT': None,
#     'MOTORCYCLE_ACCIDENT': None,
#     'TRUCK_ACCIDENT': None,
#     'NOT_PRIVATE_PROPERTY': 'Y',
#     'ALCOHOL_INVOLVED': None,
#     'STWD_VEHTYPE_AT_FAULT': '-',
#     'CHP_VEHTYPE_AT_FAULT': '99',
#     'COUNT_SEVERE_INJ': 0,
#     'COUNT_VISIBLE_INJ': 0,
#     'COUNT_COMPLAIN_PAIN': 0,
#     'COUNT_PED_KILLED': 0,
#     'COUNT_PED_INJURED': 0,
#     'COUNT_BICYCLIST_KILLED': 0,
#     'COUNT_BICYCLIST_INJURED': 0,
#     'COUNT_MC_KILLED': 0,
#     'COUNT_MC_INJURED': 0,
#     'PRIMARY_RAMP': '-',
#     'SECONDARY_RAMP': '-',
#     'LATITUDE': 0,
#     'LONGITUDE': 0,
#     'TIMECAT': 1500,
#     'MONTH_': 1,
#     'CITY': 'LOS ANGELES',
#     'COUNTY': 'LOS ANGELES',
#     'STATE': 'CA',
#     'POINT_X': -118.275500000195,
#     'POINT_Y': 34.0974617004395,
#     'Match_addr': 'HYPERION AVE & UDELL CT, LOS ANGELES, CA, 90027',
#     'm_primaryrd': 'HYPERION AVE',
#     'm_secondrd': 'UDELL CT'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.27549999999997, 34.09746170000005]}},
#   ...]}

# %% [markdown]
# ##### Write out to disk
# Especially if you are requesting dynamic data (data that is sensitive to the time at which you queried it), it is good practice to move the data out of memory (your variable) and into persistent disk storage (a file) before you do anything else with it. Although this process seems a bit redundant, it will make more sense in a bit...espeically when we are doing multiple API calls.
#
# Let's write some code to save the JSON data from our API call into data/. We are going to be using the [json](https://docs.python.org/3/library/json.html) python library for reading & writing json data. _Hint: Make sure you setup the project directory structure correctly or you will get an error!_

# %%
import json

# Write out JSON to data/ or data/raw 
with open('data/raw/collisions_2009to2013.json', 'w') as outfile:
    json.dump(resp.json(), outfile)

# %% [markdown]
# ##### Read back in the JSON data & parse to a dataframe
# Now that we have the stored to disk, let's read it back into memory and wrangle it into a more 'tidy' format for further analysis.

# %%
# TODO: Read the file into memory, store JSON as `collisions` variable
with open('data/raw/collisions_2009to2013.json') as json_file:
    collisions = json.load(json_file)

# %% [markdown]
# If you remember from the lecture earlier with the sf data portal, you can construct a dataframe directly from JSON-formatted data.

# %%
# Import pandas package
import pandas as pd

# Convert the JSON to a dataframe format
collisions_df = pd.DataFrame(collisions['features'])

# Show the head of the dataframe
collisions_df.head()
# Out:
#                                             geometry  \
# 0  {'type': 'Point', 'coordinates': [-118.3205799...
# 1  {'type': 'Point', 'coordinates': [-118.2629353...
# 2  {'type': 'Point', 'coordinates': [-118.2540335...
# 3  {'type': 'Point', 'coordinates': [-118.1771981...
# 4  {'type': 'Point', 'coordinates': [-118.2574799...
#
#                                           properties     type
# 0  {'OBJECTID': 4001, 'CASE_ID': '4127182', 'ACCI...  Feature
# 1  {'OBJECTID': 4002, 'CASE_ID': '4127195', 'ACCI...  Feature
# 2  {'OBJECTID': 4003, 'CASE_ID': '4127211', 'ACCI...  Feature
# 3  {'OBJECTID': 4004, 'CASE_ID': '4127215', 'ACCI...  Feature
# 4  {'OBJECTID': 4005, 'CASE_ID': '4127220', 'ACCI...  Feature

# %% [markdown]
# You will see that the `geometry` column holds a JSON-formatted object with our lat/lon values and the `properties` column contains a JSON-formatted object with the rest of our data related to each collision. Following the example from the SF Data Portal earlier, create a separate column for `lat` and a separate column for `lon` that holds each value for each collision.

# %%
# Create empty lat/lon lists, 
latitudes = []
longitudes = []

# loop through DF geom objects, then join lists back to dataframe
for label, row in collisions_df.iterrows():
    if pd.notnull(row['geometry']):
        # TODO: append the first list item to `longitudes` and the second list item to `latitudes`
        latitudes.append(row['geometry']['coordinates'][1])
        longitudes.append(row['geometry']['coordinates'][0])
        

        
    else:
        latitudes.append(None)
        longitudes.append(None)
        
collisions_df['lat'] = latitudes
collisions_df['lon'] = longitudes

# %%
# Examine the new dataframe
collisions_df.head()
# Out:
#                                             geometry  \
# 0  {'type': 'Point', 'coordinates': [-118.3205799...
# 1  {'type': 'Point', 'coordinates': [-118.2629353...
# 2  {'type': 'Point', 'coordinates': [-118.2540335...
# 3  {'type': 'Point', 'coordinates': [-118.1771981...
# 4  {'type': 'Point', 'coordinates': [-118.2574799...
#
#                                           properties     type        lat  \
# 0  {'OBJECTID': 4001, 'CASE_ID': '4127182', 'ACCI...  Feature  33.989071
# 1  {'OBJECTID': 4002, 'CASE_ID': '4127195', 'ACCI...  Feature  34.044239
# 2  {'OBJECTID': 4003, 'CASE_ID': '4127211', 'ACCI...  Feature  34.084091
# 3  {'OBJECTID': 4004, 'CASE_ID': '4127215', 'ACCI...  Feature  34.079670
# 4  {'OBJECTID': 4005, 'CASE_ID': '4127220', 'ACCI...  Feature  34.050159
#
#           lon
# 0 -118.320580
# 1 -118.262935
# 2 -118.254034
# 3 -118.177198
# 4 -118.257480

# %% [markdown]
# You'll still notice that all of our properties are within JSON objects as well. Pick any two column names within `properties` and write the loop again below to create two separate columns for those features.

# %%
# TODO: Loop through the DF, pick any two features
#       and separate them into two new columns, 
#       then examine the head of collisions_df

# creating empty lists for case id and city
case_id = list()
city = list()

# loop through DF property, and return case id and city back to dateframe
for label,row in collisions_df.iterrows():
    if pd.notnull(row['properties']):
        case_id.append(row['properties']['CASE_ID'])
        city.append(row['properties']['CITY'])
    else:
        case_id.append(None)
        city.append(None)

collisions_df['case_id'] = case_id
collisions_df['city'] = city

# View the head
collisions_df.head()
# Out:
#                                             geometry  \
# 0  {'type': 'Point', 'coordinates': [-118.3205799...
# 1  {'type': 'Point', 'coordinates': [-118.2629353...
# 2  {'type': 'Point', 'coordinates': [-118.2540335...
# 3  {'type': 'Point', 'coordinates': [-118.1771981...
# 4  {'type': 'Point', 'coordinates': [-118.2574799...
#
#                                           properties     type        lat  \
# 0  {'OBJECTID': 4001, 'CASE_ID': '4127182', 'ACCI...  Feature  33.989071
# 1  {'OBJECTID': 4002, 'CASE_ID': '4127195', 'ACCI...  Feature  34.044239
# 2  {'OBJECTID': 4003, 'CASE_ID': '4127211', 'ACCI...  Feature  34.084091
# 3  {'OBJECTID': 4004, 'CASE_ID': '4127215', 'ACCI...  Feature  34.079670
# 4  {'OBJECTID': 4005, 'CASE_ID': '4127220', 'ACCI...  Feature  34.050159
#
#           lon  case_id         city
# 0 -118.320580  4127182  LOS ANGELES
# 1 -118.262935  4127195  LOS ANGELES
# 2 -118.254034  4127211  LOS ANGELES
# 3 -118.177198  4127215  LOS ANGELES
# 4 -118.257480  4127220  LOS ANGELES

# %% [markdown]
# Nice work! We've actually taken the long way to access data from a GeoJSON object, but getting familiar with loops and dictionaries is absolutely critical for working with data in Python.

# %% [markdown]
# ### Exercise 2: Getting data from LA Metro
# Most of the time that you are querying APIs for data it will not be so straightforward to get it into a tidy format. Instead, what you will usually want to do is inspect the response content first before deciding how to proceed. Let's take a look at data from [LA Metro's Developer Portal](https://developer.metro.net/). Going to the [Metro Bus & Rail Real-time Arrivals](https://developer.metro.net/portfolio-item/real-time-arrivals/) page, we can see a variety of APIs that are publicly available. Take a look at all the [feeds](https://developer.metro.net/introduction/realtime-api-overview/realtime-api-returning-json/) returning JSON-formatted content, including route information, stop information, and realtime vehicle location information.
#
# You will notice that instead of GeoJSON, it is in a slightly different format that requires just a bit of wrangling to get it in the right format.

# %% [markdown]
# ##### Create an API Call
# Pick any of the Metro routes and, following the structure in the example, make a call to get all the current vehicles on that route. Once we get the response (assuming it is successful), let's take a look at the content.

# %%
# TODO: Write the statement to call the Metro API and get all vehicles for a particular route
#       and store the response as resp
# (No need to import the requests package again)
url = 'http://api.metro.net/agencies/lametro/routes/704/vehicles/' 
resp = requests.get(url)
resp.status_code
# Out:
# 200

# %%
# TODO: Store the JSON content as `data`
data = resp.json()

# %% [markdown]
# You will notice that instead of GeoJSON, it is in a slightly different format. We can convert a list of key, value pairs into a Pandas dataframe easily by `df = pd.DataFrame(dict)`. Let's go ahead and convert the json output into a dict. _Hint: Make sure you access the list part of the JSON output!_

# %%
# TODO: Convert the JSON output to a dataframe
metro_df = pd.DataFrame(data['items'])

# Examine the head of the dataframe
metro_df.head()
# Out:
#    heading    id   latitude   longitude  predictable route_id     run_id  \
# 0     90.0  9357  34.090706 -118.351479         True      704  704_164_0
# 1    150.0  6012  34.085976 -118.275177         True      704  704_166_0
# 2    300.0  9314  34.078426 -118.266744         True      704  704_167_1
# 3    255.0  9328  34.090816 -118.353477         True      704  704_167_1
# 4    285.0  9480  34.077396 -118.258781         True      704  704_168_1
#
#    seconds_since_report
# 0                    12
# 1                   127
# 2                    14
# 3                   126
# 4                    95

# %% [markdown]
# ##### Add a Column to the DataFrame
# One thing you will notice is that when we made the dataframe above, we are missing the timestamp of the query. If we plan to write out the data for analysis later, we need to add the time of the query as a column value. The easiest way to get the current time in Python is through the [datetime](https://docs.python.org/2/library/datetime.html) package. Take a little bit of time to look through the documentation with a particular focus on the `now()` method.
#
# Once we get the value of the current time, we can add it as a new column value to our current dataframe. Create an additonal column `call_time`. In the function, get the current timestamp of the call and add it as the value for that column.

# %%
# Import the datetime module
from datetime import datetime

# TODO: Get the current time
now = datetime.now()

# TODO: Add the current time as a value to the dataframe column `call_time`
metro_df['call_time'] = now
metro_df.head()
# Out:
#    heading    id   latitude   longitude  predictable route_id     run_id  \
# 0     90.0  9357  34.090706 -118.351479         True      704  704_164_0
# 1    150.0  6012  34.085976 -118.275177         True      704  704_166_0
# 2    300.0  9314  34.078426 -118.266744         True      704  704_167_1
# 3    255.0  9328  34.090816 -118.353477         True      704  704_167_1
# 4    285.0  9480  34.077396 -118.258781         True      704  704_168_1
#
#    seconds_since_report                  call_time
# 0                    12 2019-09-16 14:19:24.606519
# 1                   127 2019-09-16 14:19:24.606519
# 2                    14 2019-09-16 14:19:24.606519
# 3                   126 2019-09-16 14:19:24.606519
# 4                    95 2019-09-16 14:19:24.606519

# %% [markdown]
# ##### Wrap the API Call in a Function
# Let's create a function to take a Route ID and make the API call for all realtime vehicle locations on that route. Add in the code we used in the block above to also create a column with the time we called the API.
#
# _Function Input:_ Route ID
# _Function Output:_ Response Dataframe with the content response

# %%
# TODO: Create the function
import requests
import pandas as pd
from datetime import datetime

def get_vehicles_byroute(routenum):
#     url = 'http://api.metro.net/agencies/lametro/routes/' + str(routenum) + '/vehicles/'
    url = f'http://api.metro.net/agencies/lametro/routes/{routenum}/vehicles/'
    print(url)
    resp = requests.get(url)
    print(resp.status_code)
    data = resp.json()
    metro_df = pd.DataFrame(data['items'])
    metro_df['call_time'] = datetime.now()
    return(metro_df)

# %% [markdown]
# Let's take a look to make sure our function is working correctly. Run the cell below to confirm that you are getting the desired result. Go ahead and try changing the input and see how the output changes.

# %%
# Call the function for one of the routes
routedata = get_vehicles_byroute(720)

# Examine the head of the dataframe
routedata.head()
# Out:
# http://api.metro.net/agencies/lametro/routes/720/vehicles/
# 200
#    heading    id   latitude   longitude  predictable route_id      run_id  \
# 0     90.0  9349  34.061569 -118.299829         True      720  720_1122_0
# 1    325.0  9357  34.061599 -118.433718         True      720  720_1156_1
# 2     90.0  9363  34.061656 -118.316190         True      720  720_1139_0
# 3    253.0  9382  34.058697 -118.442505         True      720  720_1144_1
# 4    304.0  9350  34.047091 -118.249002         True      720  720_1156_1
#
#    seconds_since_report                  call_time
# 0                     8 2019-09-17 10:58:24.522751
# 1                     9 2019-09-17 10:58:24.522751
# 2                    10 2019-09-17 10:58:24.522751
# 3                     4 2019-09-17 10:58:24.522751
# 4                     9 2019-09-17 10:58:24.522751

# %% [markdown]
# ##### Add Functionality
# Great! Now we are able to change the route number and get a dataframe with the current location of all vehicles on the route. One of the next things we might want to do would be to get data from the route throughout the day and store it for later analysis. To do that we are going to need to add the following functionality into our function:
#
# 1. Write out the csv to the a file in our `data/processed` folder. Let's set the filename to the format `lametro_[routenum]_[timestamp].csv` (Eg. `lametro_720_2019-09-10-22-26-52.csv`). To write out the file, go ahead and use [Panda's method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html) for writing out a csv file.
# 2. Add conditional logic to only write out the file if the call was a success. If the call was not successful, print out the error message. Take a look [here](https://2.python-requests.org/en/master/user/quickstart/#response-status-codes) for some guidance.
#
# As the function gets a bit more complex, please add appropriate code comments inside to quickly convey the purpose of each code block.

# %%
# TODO: Re-write the function with the requested features
def get_vehicles_byroute(routenum):
    url = 'http://api.metro.net/agencies/lametro/routes/' + str(routenum) + '/vehicles/'
    print(url)
    resp = requests.get(url)
    
    if resp.status_code == requests.codes.ok:
        
#       print(resp.status_code)
        data = resp.json()
        metro_df = pd.DataFrame(data['items'])
#       getting call times and formatting time as string
        metro_df['call_time'] = datetime.now()
        date_time = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
#       export to csv
        filename = 'data/processed/' + 'lametro_' + str(routenum) + '_' + date_time + '.csv'
        metro_df.to_csv(filename, index = False) #getting rid of index column
#       return(metro_df)
    
    else:
        resp.raise_for_status()#the if else tests whether the call was successful by checking status codes

# %%
get_vehicles_byroute(710)
# Out:
# http://api.metro.net/agencies/lametro/routes/710/vehicles/
# 200

# %%
metro_704 = pd.read_csv('data/processed/lametro_704_2019-09-16-14-19-24.csv')
metro_704.head()
# Out:
#    Unnamed: 0  heading    id   latitude   longitude  predictable  route_id  \
# 0           0    139.0  9314  34.046761 -118.443779         True       704
# 1           1    315.0  9328  34.046238 -118.445320         True       704
# 2           2    338.0  9350  34.086888 -118.275470         True       704
# 3           3     90.0  6005  34.090706 -118.310211         True       704
# 4           4     53.0  9390  34.080639 -118.389961         True       704
#
#       run_id  seconds_since_report                   call_time
# 0  704_167_1                     7  2019-09-16 15:08:19.891303
# 1  704_166_0                    35  2019-09-16 15:08:19.891303
# 2  704_167_1                     8  2019-09-16 15:08:19.891303
# 3  704_165_0                    64  2019-09-16 15:08:19.891303
# 4  704_166_0                    34  2019-09-16 15:08:19.891303

# %% [markdown]
# Check your data folder - if everything was successful, you should see a CSV file with the data from the call.
# ##### Introduction to variable-length arguments
# We've now built a function that, for a given route, will get current vehicle location data, format it into a dataframe, and write it out to a CSV file with the current datetime. What if we were interested in 2 routes? or 3 routes? Let's build another function that takes as input a _variable number of route numbers_ and then gets the vehicle data for each of them.
#
# We will do this through the [_*args_ syntax](https://www.geeksforgeeks.org/args-kwargs-python/). Following that syntax, create a function called `get_vehicles_byroutes` that takes in a variable number of route numbers. For each route number, the function should call our other function `get_vehicles_byroute`. Between each call to our original function, add a 5 second pause to reduce the load on the server.

# %%
import time

# TODO: Finish composing the function
def get_vehicles_byroutes(*routes):
    for route in routes:
        url = 'http://api.metro.net/agencies/lametro/routes/' + str(route) + '/vehicles/'
        print(url)
        resp = requests.get(url)
        print(resp.status_code)
        data = resp.json()
        metro_df = pd.DataFrame(data['items'])
        metro_df['call_time'] = datetime.now()
        date_time = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
        filename = f'data/processed/lametro_{route}_{date_time}.csv'
        metro_df.to_csv(filename, index = False)

# %% [markdown]
# ##### Create a Loop to run the Function
# Great! We now have a function that calls the Metro's API, records the location of all vehicles for a particular route(s), logs the current timestamp, and saves the file in a location of our choosing. Let's (1) pick a few routes we want to get data from and (2) create a loop that runs the `get_vehicles_byroutes` function 1x per minute, for 5 minutes with those route numbers as the input.

# %%
# TODO: Execute the function 5x, each time separated by a minute
routes = [710, 730, 745, 720, 10, 8]
count = 0
while count < 5:
    get_vehicles_byroutes(*routes)
    time.sleep(60)
    count = count + 1
    print('running time:', count)
# Out:
# http://api.metro.net/agencies/lametro/routes/710/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/730/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/745/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/720/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/10/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/8/vehicles/
# 200
# running time: 1
# http://api.metro.net/agencies/lametro/routes/710/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/730/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/745/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/720/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/10/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/8/vehicles/
# 200
# running time: 2
# http://api.metro.net/agencies/lametro/routes/710/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/730/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/745/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/720/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/10/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/8/vehicles/
# 200
# running time: 3
# http://api.metro.net/agencies/lametro/routes/710/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/730/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/745/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/720/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/10/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/8/vehicles/
# 200
# running time: 4
# http://api.metro.net/agencies/lametro/routes/710/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/730/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/745/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/720/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/10/vehicles/
# 200
# http://api.metro.net/agencies/lametro/routes/8/vehicles/
# 200
# running time: 5
