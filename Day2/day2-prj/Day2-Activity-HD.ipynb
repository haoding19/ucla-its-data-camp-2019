# %% [markdown]
# # UCLA ITS Data Camp, Day 2

# %% [markdown]
# ### Warm-Up / Review Exercise: Get Scooter Data
# You may have seen some scooters around UCLA. What you may not have known is that the data on dockless mobility in Los Angeles is made publicly available via APIs provided by each company, which you can read more about [here](https://medium.com/tim-black/scooters-mapped-55a2afca46b1). Each company provides a separate URL for each city they operate in. I've compiled a master list of the scooter companies' GBFS feeds [here](https://github.com/black-tea/swarm-of-scooters/blob/master/data/systems.csv); for example, you will see that the Los Angeles region includes 7 different feeds across 6 providers.
#
# Using our new skills at getting data from APIs, let's practice grabbing data from these companies. Build a function that will take in a URL as an argument and will output a JSON file with the response content.
#
# _Function input:_ URL of GBFS data feed
# _Function output:_ Writes JSON to `data/raw` with filename format: `scooter_[%Y-%m-%d-%H-%M-%S].json` (no return value)

# %%
# TODO: Build a function that takes in a url and writes out the data to your `data/raw` directory.
#       Hint: Don't forget to import the necessary packages!

import requests
import json
import time
from datetime import datetime

def get_scooter_gbfs(scooter_url): 
    resp = requests.get(scooter_url)
    
    if resp.status_code == requests.codes.ok:
        with open(f'data/raw/scooter_[{datetime.now().strftime("%Y-%m-%d-%H-%M-%S")}].json', 'w') as outfile:
            json.dump(resp.json(), outfile)
    
    else:
        resp.raise_for_status()

# %% [markdown]
# Pick any of the URLs on [this page](https://github.com/black-tea/swarm-of-scooters/blob/master/data/systems.csv) to test out your function below.

# %%
# TODO: Add URL
scooter_url = 'https://mds.bird.co/gbfs/los-angeles/free_bikes'

# Run your function to download the data and store for later
get_scooter_gbfs(scooter_url)

# %%
import json
with open('data/raw/scooter_[2019-09-17-10-05-59].json') as json_file:
    bird_la = json.load(json_file)

# %%
bird_la
# Out:
# {'last_updated': 1568739959,
#  'data': {'bikes': [{'bike_id': '9d5d5fc6-aeb7-4f35-85fa-990d59ab6cfe',
#     'lat': 34.024936,
#     'lon': -118.193322,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '6b57b39f-4d46-4a93-8a1c-d2b41cba0669',
#     'lat': 34.018259,
#     'lon': -118.309285,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '084f9800-891a-4e85-8c6b-e2fbc3eb505d',
#     'lat': 34.094614,
#     'lon': -118.338552,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'eafa998c-41a3-427c-86db-822789b6b17c',
#     'lat': 34.065551,
#     'lon': -118.442585,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '931f5b50-4b08-4045-a3b9-ac85370f5e38',
#     'lat': 34.043277,
#     'lon': -118.447053,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '3d1ad672-512d-4430-b27e-e436e7ee1380',
#     'lat': 34.042396,
#     'lon': -118.256453,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'c75b618c-f1df-45a8-b22c-9e70bc57ccf9',
#     'lat': 34.04580250641606,
#     'lon': -118.23845560165303,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'afc8ce28-d3ec-41f8-ac68-5a1115885aa5',
#     'lat': 34.040121,
#     'lon': -118.258881,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '02411fcf-6cb5-471a-ae2a-4382cd51d839',
#     'lat': 33.988902,
#     'lon': -118.46243,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'e4af74e3-8fa6-4f20-a1a4-e6764be8b13f',
#     'lat': 34.026899,
#     'lon': -118.428082,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '8b88780f-c8fe-4c6f-8bb2-fb85bdda8224',
#     'lat': 34.065775,
#     'lon': -118.445856,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '1f9a26e9-53ef-4337-b300-cb0a8e2c2150',
#     'lat': 34.065916,
#     'lon': -118.43987,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b2b7c719-76e4-4930-8395-535a76d82d10',
#     'lat': 34.063245,
#     'lon': -118.445015,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b57bbb50-abab-4689-a1f7-195882df535b',
#     'lat': 34.090951,
#     'lon': -118.322394,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '1337d501-5694-4bb0-a999-7ba6ef23f2eb',
#     'lat': 33.994004,
#     'lon': -118.453303,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '64171c1d-3271-429d-99a6-cc0ea8969b9d',
#     'lat': 34.075583,
#     'lon': -118.439185,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '49fcb220-2622-417d-b4de-ccf9acd86988',
#     'lat': 34.083126,
#     'lon': -118.35117,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f557252c-4a09-40f0-9418-86d5b80b801f',
#     'lat': 34.044599,
#     'lon': -118.257386,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '00e8a3d8-e549-4ea3-bc5d-826e65c3251f',
#     'lat': 33.990464,
#     'lon': -118.462049,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '336562ae-333a-4356-b147-373d6f673bb6',
#     'lat': 34.037421,
#     'lon': -118.462824,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '779344a3-c40f-4ace-b537-57ca85b4dbf1',
#     'lat': 34.042748,
#     'lon': -118.450574,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'af830738-4f28-424f-a760-a373a05c1b39',
#     'lat': 34.018606,
#     'lon': -118.421916,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '4946a1ba-52a3-43ae-835b-1f279b0ff414',
#     'lat': 33.991068,
#     'lon': -118.465917,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5509fc4d-15a9-48b7-b812-c5be68dd1104',
#     'lat': 33.994933,
#     'lon': -118.463031,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'dfa5d64a-2684-4e47-8871-3fc27781eab4',
#     'lat': 34.043879,
#     'lon': -118.467237,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '03b5484b-2f67-45ef-9cfc-9d9ec98b04dc',
#     'lat': 33.9951,
#     'lon': -118.451057,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '8b27e8a9-3bfc-47e1-97d7-a3f319a3fff8',
#     'lat': 33.989592,
#     'lon': -118.446423,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f3dd3144-7384-4a34-a50b-ce780122e009',
#     'lat': 34.038392,
#     'lon': -118.441293,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '443cfbed-0874-4bdd-9d16-86ffa65b3e87',
#     'lat': 34.000519,
#     'lon': -118.465925,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'aaee5c49-f23f-443e-96a8-e0e57117f1a0',
#     'lat': 34.044068,
#     'lon': -118.446231,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5cca8ffa-1e22-4670-af78-7219ed2df05d',
#     'lat': 33.993716,
#     'lon': -118.466036,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '48b00d9e-5439-4cd3-b541-a0b5fad88c10',
#     'lat': 34.002869,
#     'lon': -118.459812,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b6528e33-21be-4b9f-9b88-e77852d8de52',
#     'lat': 34.045474,
#     'lon': -118.253615,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '6908de57-58ac-48b9-bb9c-1e2ce5cdb45f',
#     'lat': 33.99096,
#     'lon': -118.465905,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '8a267b37-cae2-425f-81b0-6ef749f7df1b',
#     'lat': 33.989869,
#     'lon': -118.448786,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '98627f3e-673c-447d-a553-0e6e137deedb',
#     'lat': 34.083362,
#     'lon': -118.355356,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b75d6e0c-87fa-47b3-adee-96e05ace68f3',
#     'lat': 33.969803,
#     'lon': -118.454866,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'e46018bd-05cf-4c6f-a157-317b91329d6b',
#     'lat': 33.98796,
#     'lon': -118.46049,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '22c63d81-94c4-43ce-ad5c-1836dce2ba8f',
#     'lat': 33.991583,
#     'lon': -118.465334,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '874fe4ed-d35e-4055-8022-c8af0af5fa80',
#     'lat': 33.988122,
#     'lon': -118.445748,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'ff2b1256-54c8-43ae-92ee-6af5baa5d2dd',
#     'lat': 34.054071,
#     'lon': -118.250101,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '1abff595-2a98-42a2-bd5c-a8417af5f57a',
#     'lat': 33.990477,
#     'lon': -118.464698,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '7ac6dac9-81ee-4e87-a65b-a344dd468075',
#     'lat': 34.026505,
#     'lon': -118.371813,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '1ff19453-cd9b-4f28-975f-cd03d460e95d',
#     'lat': 33.995956,
#     'lon': -118.449675,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'd4f5d673-2b31-466f-88d0-d6434d8e3c24',
#     'lat': 34.002616,
#     'lon': -118.449426,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '6fd03b4b-aadf-4542-a395-173e8515d346',
#     'lat': 33.992947,
#     'lon': -118.451389,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f3c9325e-b5fc-4d1e-a10c-b34cb4f9cfdc',
#     'lat': 34.083452,
#     'lon': -118.355296,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b3bfa762-fc18-4884-9c08-a49a86911d81',
#     'lat': 34.023250755885634,
#     'lon': -118.2837418467908,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '7e193c35-3508-484a-836e-111766f99015',
#     'lat': 33.998303,
#     'lon': -118.473569,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'bfb3b8fc-8b1e-49e1-9174-e365b0fb4555',
#     'lat': 34.022276,
#     'lon': -118.42198,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '6722dcc9-7265-497c-b42b-6f20549c9de3',
#     'lat': 34.049028,
#     'lon': -118.257267,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'd19ac86e-c22e-4c60-900d-794df3cd50fe',
#     'lat': 33.99854,
#     'lon': -118.473872,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '718051f7-b55e-4027-83f9-cd12f9e9afd9',
#     'lat': 34.04073402814217,
#     'lon': -118.26672063347897,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2ce3b7f7-6cc1-45a9-84b7-75987e9e8e95',
#     'lat': 34.022277,
#     'lon': -118.421965,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '144763fd-5355-4547-80f5-aef2700b3c4d',
#     'lat': 33.999185,
#     'lon': -118.442303,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '754f891c-2014-4956-a43b-89418b2acb30',
#     'lat': 34.023933,
#     'lon': -118.280097,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2b213899-6c32-4aa1-bdda-b59085774415',
#     'lat': 33.989658,
#     'lon': -118.461113,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'c3443737-0abc-4f9f-91a2-f3ba2838b771',
#     'lat': 34.048911,
#     'lon': -118.241082,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'e94d315d-c00b-415b-be27-112eef413d13',
#     'lat': 34.000095,
#     'lon': -118.465928,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '8f97ecd1-177e-4853-9368-f8e6f3688926',
#     'lat': 33.999938,
#     'lon': -118.47062,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '23e24c49-911b-4a1b-815b-e690e3e055fd',
#     'lat': 34.037018,
#     'lon': -118.435502,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'be9bdca9-fd42-4ca2-b1c8-af4ca0394faa',
#     'lat': 33.989664,
#     'lon': -118.461227,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '0c79c42e-e763-4c6e-a8c0-09ec289313e4',
#     'lat': 34.000869,
#     'lon': -118.439746,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5f8b628f-1172-4a9d-b6bb-505d58e41d93',
#     'lat': 33.999826,
#     'lon': -118.47081,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '1b666e58-3440-4703-8a56-17e704426379',
#     'lat': 33.989624,
#     'lon': -118.461241,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '6a02c761-4ded-4cb1-9e7a-63cc0a5b66c7',
#     'lat': 33.989675,
#     'lon': -118.461303,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b99a66e1-f24e-443f-8757-768c0129a9e4',
#     'lat': 34.048137,
#     'lon': -118.257759,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '9b4851bb-0ad2-4349-b25b-f0072f713d1a',
#     'lat': 33.989583,
#     'lon': -118.46118,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'e5b8d37a-f869-4be0-9fd9-6b66c26e7af8',
#     'lat': 34.02062,
#     'lon': -118.256574,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '1b9f860d-0c10-4cdf-b260-43acd823d97d',
#     'lat': 33.989697,
#     'lon': -118.461017,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2dd53896-0208-4f62-83e7-45ccefbc5314',
#     'lat': 33.988121,
#     'lon': -118.460297,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '9a4c95d6-28cc-4ba5-8f2f-0feabb5689fe',
#     'lat': 33.997608,
#     'lon': -118.475243,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '845c2608-ca9c-4dc8-849a-a0f29586ec55',
#     'lat': 33.998549,
#     'lon': -118.460946,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f24d871c-3863-44e1-a108-0a8582ba9b21',
#     'lat': 33.998558,
#     'lon': -118.460957,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '36731b85-511d-4110-9bcb-2058a1a27e25',
#     'lat': 34.080441,
#     'lon': -118.361534,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'ef45bafc-ce58-469d-b022-c684a18edee5',
#     'lat': 34.027182,
#     'lon': -118.256408,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2bc8a229-269d-4b28-a1c9-5535598094ef',
#     'lat': 34.08907,
#     'lon': -118.29419000000001,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '14bf4ec7-5d8e-4d8d-b3cd-dd64adbb0c3c',
#     'lat': 33.98781,
#     'lon': -118.452615,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'e3d1b9bc-d290-4686-a3cd-b7bb795d72a1',
#     'lat': 33.987825,
#     'lon': -118.452618,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '8fd0432a-1f3e-4a3e-8ee2-ada99818fa80',
#     'lat': 33.987859,
#     'lon': -118.458879,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '842af139-c2dc-4ca9-b20a-439e86de0611',
#     'lat': 33.987785,
#     'lon': -118.452633,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '4112f7c3-560e-4661-8a02-e40163d9b5d2',
#     'lat': 33.999119,
#     'lon': -118.442299,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '861f9c97-a821-4b43-aafc-bc193157f1ef',
#     'lat': 34.008118,
#     'lon': -118.442534,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '1dfca5ea-bc34-4aa9-8203-368b3ed5926d',
#     'lat': 34.01738,
#     'lon': -118.267202,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '412e2a0d-fcd4-4e20-9ab7-aa118e0299e6',
#     'lat': 33.99074814707787,
#     'lon': -118.4654359659703,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f2e463ee-47f2-459d-a5bc-eef3dc8c0dbb',
#     'lat': 33.957742,
#     'lon': -118.434912,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '4c421a44-4ec7-43cd-84ac-7ada0eaa5b08',
#     'lat': 34.040543,
#     'lon': -118.263315,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '187b57d1-996b-4177-bedf-097e217461cf',
#     'lat': 33.987823,
#     'lon': -118.459472,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '7c15580d-8018-4aaa-bd7e-dc724324c2e9',
#     'lat': 34.173027067477044,
#     'lon': -118.59763288881499,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '45d78cca-c16d-42bf-acd7-3c95ca7e8549',
#     'lat': 33.99258,
#     'lon': -118.466533,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'fe189b93-5407-49c1-8d03-2d87075c2ad8',
#     'lat': 34.029209,
#     'lon': -118.403791,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '191ff625-2e5b-4e0a-9895-a05accd951de',
#     'lat': 33.999695,
#     'lon': -118.471416,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'c0671939-f840-4c90-a0c0-c8b7989fbfeb',
#     'lat': 33.987792,
#     'lon': -118.459515,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a3ac56dc-263d-4267-a7e9-abc784bd54ce',
#     'lat': 33.977393,
#     'lon': -118.418636,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '80fbab34-0fba-4653-b99d-9d4716a69cef',
#     'lat': 33.999245,
#     'lon': -118.442294,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5f87e4c9-4298-4147-90b3-6c258a79dfef',
#     'lat': 33.999187,
#     'lon': -118.442346,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '7e1034f3-5dc0-49ce-855d-180d6953108a',
#     'lat': 34.048662,
#     'lon': -118.242123,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b9b622e5-b2a8-413d-b943-c7f0db937f7b',
#     'lat': 34.045586,
#     'lon': -118.456089,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '63b4510d-3e25-4fc2-a2ba-4746bde9318d',
#     'lat': 34.073308,
#     'lon': -118.443723,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '96f820c1-8c74-4a67-946b-107cca4f66aa',
#     'lat': 34.02820823874607,
#     'lon': -118.45242089465322,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f8c52aff-208d-4119-af40-a6200e560043',
#     'lat': 34.034991,
#     'lon': -118.448609,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '0c368ff8-f096-4d5a-b273-e3c13cb908f4',
#     'lat': 33.997643,
#     'lon': -118.475235,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'bbbebe97-6e7a-45ed-9e05-1358f76f8e98',
#     'lat': 34.100338,
#     'lon': -118.323651,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '27c696df-de0c-46b9-a7b7-ae5cce3a4fbf',
#     'lat': 33.98786,
#     'lon': -118.452513,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'cce49131-c4ea-4e2e-9a1a-c0f3ef1f7b0d',
#     'lat': 33.990267,
#     'lon': -118.464181,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b15e76c3-b3f2-4fe5-85ac-c2fadd518a8e',
#     'lat': 33.980806,
#     'lon': -118.438988,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'ef3aabcb-017a-4e64-bc88-9111fd0e5ab6',
#     'lat': 34.053108,
#     'lon': -118.242254,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '87d75d30-f2b1-4f66-b28b-e1ba42accba7',
#     'lat': 33.994522,
#     'lon': -118.468068,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '89880a27-1150-4eb6-9aa5-59c785785d88',
#     'lat': 34.017724,
#     'lon': -118.409062,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a1b33217-4e6f-40a0-9d97-e106cc5c9505',
#     'lat': 33.990966,
#     'lon': -118.459279,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a4cd027c-79aa-4604-9a81-42519ed869bb',
#     'lat': 33.990951,
#     'lon': -118.459282,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '1b4eecd8-0655-4e51-9b15-b05f4b01381a',
#     'lat': 34.041015,
#     'lon': -118.262591,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '977adebd-6cd0-49aa-8782-b6d6969e24ba',
#     'lat': 34.005254,
#     'lon': -118.430317,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '04cbc688-b02d-400b-bd8a-223afaf22584',
#     'lat': 34.003861,
#     'lon': -118.462777,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2ae5c9bd-bf64-491d-9535-a09975fee14a',
#     'lat': 34.027547,
#     'lon': -118.26279,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'eceb2401-46c7-44fc-896f-62dca28dc75e',
#     'lat': 34.053314,
#     'lon': -118.465316,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'cdd37277-aa63-4ad9-ad1b-35e688fffaf3',
#     'lat': 34.001851,
#     'lon': -118.459546,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5bfff58d-4155-4b59-af22-adbd40c4dc45',
#     'lat': 34.005256,
#     'lon': -118.430336,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '322ba59e-03d0-46cb-a907-06e8297fc614',
#     'lat': 34.084928,
#     'lon': -118.313661,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5c7ef464-e228-45a3-84c4-4c2849b8b7a4',
#     'lat': 34.053302,
#     'lon': -118.465353,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '004359d8-2463-46af-9b91-5f07385a388b',
#     'lat': 33.997249,
#     'lon': -118.460493,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'c266c197-7562-4402-b2f1-9b99a2cc3304',
#     'lat': 33.992814,
#     'lon': -118.453838,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '3d67c18b-1de2-42b7-b9d0-57c50dfa2d61',
#     'lat': 33.992837,
#     'lon': -118.464599,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '69bf39d3-235d-4c22-b44a-52d0a93bf1aa',
#     'lat': 33.994881,
#     'lon': -118.454921,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f480b3a0-a757-4e76-94e0-df9fb7ae1c33',
#     'lat': 34.001271,
#     'lon': -118.461183,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a1b07573-7e9c-4fd9-907b-c6e7095d55d0',
#     'lat': 33.991322,
#     'lon': -118.468401,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'c527a62e-5ed0-400e-a8b9-81f04b646b9d',
#     'lat': 34.06884,
#     'lon': -118.453699,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '02f50a4a-40f7-4642-81f5-d7fc11cbbaac',
#     'lat': 34.002734,
#     'lon': -118.45977,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '3190aaab-5de9-41b0-9fbc-158c06c53687',
#     'lat': 33.997644,
#     'lon': -118.47531,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '38da7ad6-6ef5-4064-8384-b76aca284881',
#     'lat': 33.998549,
#     'lon': -118.460927,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'ee741b47-ccf8-464f-9670-e7ea053b8d60',
#     'lat': 34.018492,
#     'lon': -118.309269,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b25a19aa-e982-4a1e-9a35-8a307e94a70e',
#     'lat': 34.013275,
#     'lon': -118.417386,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b2b31eab-7f17-47f2-9fe3-586035b85409',
#     'lat': 34.077124,
#     'lon': -118.354297,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2b919214-371d-4eb0-bcdf-1a2a8f509e15',
#     'lat': 33.994557,
#     'lon': -118.468088,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'ef5d1ba8-bb94-45f4-b952-7152167f3e89',
#     'lat': 34.029317,
#     'lon': -118.281177,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'dab367ef-6fd1-4763-a911-07b6a4ecfeb7',
#     'lat': 33.994482,
#     'lon': -118.46802,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a23daf61-f72a-49ad-9acc-7943367cdc31',
#     'lat': 34.048326,
#     'lon': -118.239284,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '936fb9ce-a8fc-446c-b377-93532a8e8611',
#     'lat': 33.994519,
#     'lon': -118.468207,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '13f24978-f222-46ca-929f-d28b19633280',
#     'lat': 34.002814,
#     'lon': -118.459852,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '052e00d7-d65c-48a0-a9ea-5f6b8b598ea2',
#     'lat': 33.9945,
#     'lon': -118.468135,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '78ef450e-8e74-486f-8928-021d486e8bbf',
#     'lat': 34.037264,
#     'lon': -118.435158,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '50a3723c-fd92-4876-895b-e731b9ac54e0',
#     'lat': 34.073562,
#     'lon': -118.383654,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '8d637966-d09a-459a-9fc2-197556468eb6',
#     'lat': 34.023932,
#     'lon': -118.283945,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '0871049e-0c74-42c4-9d80-4b0e396c0818',
#     'lat': 34.025379,
#     'lon': -118.252314,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '27d5bdeb-edb2-4832-b79b-f244126c0f0b',
#     'lat': 34.00015,
#     'lon': -118.465888,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'd859cc1a-dcf9-4d6e-9992-f6b2b7b1c3e3',
#     'lat': 34.054737,
#     'lon': -118.268573,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '47ff494f-e33b-4e4f-bccb-2ed9c89cff34',
#     'lat': 34.068014,
#     'lon': -118.439072,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '7ea1b90f-cf8c-42ac-8959-61c4d15d388c',
#     'lat': 34.018085,
#     'lon': -118.286152,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'd8275cfc-2a52-485d-b94f-ba95a41a9da2',
#     'lat': 34.052634,
#     'lon': -118.467902,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '79530c4d-57d9-4429-ac1c-2d96d19091a7',
#     'lat': 34.066745,
#     'lon': -118.345281,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '4978294a-73fd-4da9-8497-e4fef88dd5c0',
#     'lat': 33.9908482,
#     'lon': -118.4659178,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b4bf9a4b-6259-4da0-b3ab-69c2ab212ab4',
#     'lat': 34.033081,
#     'lon': -118.283442,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '22cb54e1-9026-480c-82dd-1f5296743c2e',
#     'lat': 34.052616,
#     'lon': -118.467896,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'dba8fca0-9fa5-4ff6-959f-bac668e3593f',
#     'lat': 34.034582,
#     'lon': -118.44767,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '9f5f3a7a-3726-44ee-bc0f-966e9d90675f',
#     'lat': 33.979639,
#     'lon': -118.462336,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '91759cf0-1d6c-4d8e-9627-52f8c1b834e1',
#     'lat': 33.994255,
#     'lon': -118.452986,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'e4ed8a24-9e51-4866-9e1f-ab869b2bfa61',
#     'lat': 34.029397,
#     'lon': -118.410674,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b48946b5-6047-4443-9ebf-7fac3c7f12c3',
#     'lat': 34.052166,
#     'lon': -118.252368,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '95d0992f-38f9-46ea-89a7-0889c3b122e3',
#     'lat': 34.048648,
#     'lon': -118.255251,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '9edf7051-2219-4f8f-8687-ee69dfce4c01',
#     'lat': 34.062254,
#     'lon': -118.445577,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '24212983-6719-464c-9be9-c41e747b5492',
#     'lat': 34.085395,
#     'lon': -118.33851,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'fe62c5c3-01b7-440d-ac61-8179b05134dc',
#     'lat': 34.033512,
#     'lon': -118.446441,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a430d6fd-a386-4221-a015-4fc61d50b13c',
#     'lat': 34.046737,
#     'lon': -118.257202,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '103307f6-3a5f-43b1-9a60-4c5ad2689107',
#     'lat': 34.036302,
#     'lon': -118.442549,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'c76b639d-2124-4e88-80be-394501e3f87a',
#     'lat': 33.994204,
#     'lon': -118.452606,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5c0d9da2-ca39-489f-8a5e-75b08631cc69',
#     'lat': 34.036177,
#     'lon': -118.444162,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'e851c319-544a-45f5-8bd8-78464f3edf28',
#     'lat': 34.071002,
#     'lon': -118.442441,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'df5d680e-609d-4a56-8447-be54dbc15e46',
#     'lat': 34.062801,
#     'lon': -118.308993,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'ad48cad8-42ec-454a-bfaf-cf60133479c8',
#     'lat': 34.02714932012661,
#     'lon': -118.39268346759334,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '30f1a35e-e7ae-48fe-b69c-5d0ca7c01157',
#     'lat': 33.99069,
#     'lon': -118.465841,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '04f9ef93-11b7-4c8d-be45-057492d7930c',
#     'lat': 34.027252,
#     'lon': -118.392886,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '068b9f75-a9ee-4fc4-b6a4-d500ea8449f1',
#     'lat': 34.040492,
#     'lon': -118.268327,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f91fec64-ecc3-4f45-8439-a2457ae359ba',
#     'lat': 34.093736,
#     'lon': -118.308554,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'da09615e-fedd-4a71-863e-498b63e8916c',
#     'lat': 33.987828,
#     'lon': -118.45881,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f85a656e-aa25-41ce-af76-49308c222859',
#     'lat': 34.040811,
#     'lon': -118.26104,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '46799735-5aea-4690-883d-bfd32355113c',
#     'lat': 34.052374,
#     'lon': -118.29137,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'bfe38752-3469-4490-8b4b-b063e958ff0d',
#     'lat': 34.091192,
#     'lon': -118.332548,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '7971ef75-722b-4574-aaf3-e3f611b92c41',
#     'lat': 34.026284,
#     'lon': -118.408592,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'df4fa285-2ff5-415c-a015-4889a6ccaa3e',
#     'lat': 34.073786,
#     'lon': -118.440966,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '775d471e-b7d8-4f3a-bb78-3dc736a29e97',
#     'lat': 33.997661,
#     'lon': -118.475116,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'dcbc88fe-4cfd-4336-b41e-2b7f0cdaa6dc',
#     'lat': 34.023606,
#     'lon': -118.284068,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '0aef9114-155c-49f5-b856-b58020c02ad2',
#     'lat': 34.009995,
#     'lon': -118.432582,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '58d9a7e2-7c98-45a0-83b9-2bab9e112e4d',
#     'lat': 34.075801,
#     'lon': -118.37678,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '7fed0b6a-f241-47cd-8b28-cb60efa5d10e',
#     'lat': 33.987949,
#     'lon': -118.458917,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '66c4052f-9801-4496-93ed-a780b3ef6744',
#     'lat': 34.03598997078327,
#     'lon': -118.45821733124289,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a8ba307b-1d83-4137-83c7-6d2f98cfb63f',
#     'lat': 33.819668,
#     'lon': -118.308463,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '82b98ac2-39ac-4622-9759-d723608e3d18',
#     'lat': 34.019814,
#     'lon': -118.409085,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '38ce9961-932b-471b-8e37-7c738796ec5d',
#     'lat': 33.986249459680835,
#     'lon': -118.44230723658336,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'ce973ea7-d6ff-42ea-9bbe-e5e57563ad7d',
#     'lat': 34.000057,
#     'lon': -118.465808,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '9f7dc584-3beb-4f7c-9d22-29246a79af4c',
#     'lat': 34.072901,
#     'lon': -118.372451,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'da899055-5207-4fc3-9b8f-880cb61d718c',
#     'lat': 34.185116,
#     'lon': -118.451177,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2f996ecb-f597-4c43-b38c-1ac3ea472327',
#     'lat': 34.04821,
#     'lon': -118.233945,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '8c8eca2a-d99f-4347-a0e3-3bf269cac41a',
#     'lat': 34.065583,
#     'lon': -118.445187,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'e86117af-0f1d-4646-987a-299cfd66eb79',
#     'lat': 34.048476,
#     'lon': -118.257275,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '0be243db-e7fa-4f28-a570-09b7b5e6b202',
#     'lat': 33.993066,
#     'lon': -118.459916,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'c907a8be-b561-47e9-8866-2d20325e3baa',
#     'lat': 34.041533,
#     'lon': -118.262816,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'acde853a-6f58-4eb6-894f-411ebd23861d',
#     'lat': 34.076141,
#     'lon': -118.367689,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'ebb90b5e-0218-40a5-89ba-34c01b5b4f0f',
#     'lat': 34.06623833333333,
#     'lon': -118.35299000000002,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '0c67d4d5-4615-43db-9a99-c8ba4046497d',
#     'lat': 34.003312,
#     'lon': -118.433891,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a730cb28-bb3b-4f5d-9663-1bb91c79f0d5',
#     'lat': 34.049397,
#     'lon': -118.241786,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '8e0062d8-f60e-4d8d-b0ad-a5f813419871',
#     'lat': 34.047079,
#     'lon': -118.241805,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '095e01f9-3407-4d1f-bb5c-ff430a6219bd',
#     'lat': 34.048265,
#     'lon': -118.257907,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'cd25972e-9ae3-4fea-a6f8-a235fd858f2e',
#     'lat': 34.051205,
#     'lon': -118.249869,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '10d4920e-63cd-4a94-bbd8-92aaff9633b8',
#     'lat': 34.061013,
#     'lon': -118.260491,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '47ffe504-d29f-4de7-a86b-3eb4c5393715',
#     'lat': 34.094941,
#     'lon': -118.342895,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f8d0417b-fee0-4a3b-9e11-b088f448cb32',
#     'lat': 34.019463,
#     'lon': -118.40776,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'bba9fb8e-6d8a-48ac-8f2e-8c692ff2cd4a',
#     'lat': 34.068548,
#     'lon': -118.444638,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '61b30c40-7da7-47dd-99b5-eed2bdede2cb',
#     'lat': 34.006664,
#     'lon': -118.452637,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '553f2440-38b6-4b08-b6da-a24ed3082916',
#     'lat': 34.062502,
#     'lon': -118.35128,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '0d5339db-0b56-47c1-b873-acc622f5ffe8',
#     'lat': 34.075864,
#     'lon': -118.260652,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5996b07f-0f96-4c4a-905a-a9ced0238f40',
#     'lat': 33.985638,
#     'lon': -118.443816,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'ac9edb59-597e-453b-90f3-2a435b18d30c',
#     'lat': 34.101654,
#     'lon': -118.346958,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '795cfbc3-5d1f-45f2-a74a-3ffcdf61a7f6',
#     'lat': 34.077704,
#     'lon': -118.259801,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'd313ab37-d512-4570-a7de-3ddef144c46b',
#     'lat': 33.99136,
#     'lon': -118.44077333333334,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'fb8d32b5-cb76-4a48-9bb1-428fb6cfe60c',
#     'lat': 34.022926,
#     'lon': -118.376207,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'fddb1e08-b476-459d-800b-aa94a2d2dc63',
#     'lat': 33.989491,
#     'lon': -118.446258,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '267d82ba-c231-4495-94a3-06bb8aed47a0',
#     'lat': 34.066789,
#     'lon': -118.447406,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '9a204199-6169-457f-91b6-7649f291bd1f',
#     'lat': 34.059592,
#     'lon': -118.444225,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '0e5f9150-48d8-4829-9f9e-a07eaff8ad90',
#     'lat': 34.045604,
#     'lon': -118.265802,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '0cb803f8-10f5-4cbc-8b2f-051e358e7621',
#     'lat': 34.098154,
#     'lon': -118.309866,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '776a6ddf-f3c8-435d-8df8-dc4648c445de',
#     'lat': 34.039277,
#     'lon': -118.265245,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '12fd02e0-fd7c-4208-9a02-8c60a8bfa361',
#     'lat': 34.043052,
#     'lon': -118.253749,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '67aafcce-e8a6-42f9-b120-0c46fba38622',
#     'lat': 34.087755,
#     'lon': -118.348667,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '98453591-2de4-4b88-8bb4-2e5c3031acf4',
#     'lat': 34.060795,
#     'lon': -118.445076,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'ba2b6de7-a8c7-4b6f-8d24-0fb48ef84080',
#     'lat': 34.040366,
#     'lon': -118.268122,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2b87eef9-f60d-4dc8-88fa-7f31ba27d73c',
#     'lat': 34.045667,
#     'lon': -118.250846,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'e20cd2a2-1c73-43c0-afa9-0bbdc56975c6',
#     'lat': 34.05145,
#     'lon': -118.255998,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'ed903881-2859-4d5e-ad6c-df0f8f118d47',
#     'lat': 33.990433,
#     'lon': -118.464921,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '64f35937-2d1b-4185-b004-ca660863f30a',
#     'lat': 34.054684,
#     'lon': -118.407979,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5af53c30-5f0e-4b70-b3b2-6ac65c4cc8fc',
#     'lat': 34.048697,
#     'lon': -118.258975,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '550913ee-6b81-4fe1-9ffc-a6af0b525183',
#     'lat': 34.046438,
#     'lon': -118.250168,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b6cf079f-0a93-4533-b749-3f8906979439',
#     'lat': 34.054161,
#     'lon': -118.262219,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '11ec291e-d044-4e82-85d5-27f733b095b5',
#     'lat': 34.07230833333333,
#     'lon': -118.35704833333332,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f832ae51-d2fe-43e2-8f16-b79871bdbbf1',
#     'lat': 34.034506,
#     'lon': -118.272724,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a7efb57c-bd86-4676-9f61-deebb2e6d4b6',
#     'lat': 34.21676,
#     'lon': -118.468077,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '6e519f17-5c1a-4d4f-bb87-99155636bd60',
#     'lat': 34.070382,
#     'lon': -118.450984,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '493b2ef6-2edb-4000-b1c8-0b48d61cf3cd',
#     'lat': 34.06296,
#     'lon': -118.299385,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f5874b8b-b8ac-4494-a126-70c4094e6586',
#     'lat': 33.990341,
#     'lon': -118.464904,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '71235ffe-5468-4d0a-aa97-3b11bfdbb4f0',
#     'lat': 34.011048,
#     'lon': -118.268222,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'e1ecf227-3998-4a77-87de-8470a517515c',
#     'lat': 34.057125,
#     'lon': -118.276472,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '336e2ded-41bd-4bf8-b92c-3c364f75f713',
#     'lat': 34.050158,
#     'lon': -118.248872,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '4ac51534-ae14-434a-89c9-58f14b0f5bc8',
#     'lat': 34.077723,
#     'lon': -118.258036,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '65fac495-ae40-4177-b5af-9efe8ac09a66',
#     'lat': 34.063539,
#     'lon': -118.350215,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a908e495-e7c6-45e8-aa96-de0f93b78e07',
#     'lat': 34.054343,
#     'lon': -118.262552,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'db301dca-9fde-489b-bfa6-d9c5d7c3534b',
#     'lat': 34.025643,
#     'lon': -118.283739,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'd2871442-c054-43d6-8c40-121d8fbbb865',
#     'lat': 34.02182,
#     'lon': -118.314008,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'fd647546-6f9c-4bc9-8f19-575224337247',
#     'lat': 34.071224,
#     'lon': -118.303276,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '912eee89-cb6a-4ba4-be89-879d0e5a1c2b',
#     'lat': 34.046763,
#     'lon': -118.259952,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f5587ac8-a761-406b-89fe-f98c788c1ed9',
#     'lat': 34.087424,
#     'lon': -118.348753,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '46ea114a-7d05-4d87-bb86-2a2cba42d070',
#     'lat': 34.062512,
#     'lon': -118.290178,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '36b2ebf2-5c26-49ca-8f4b-33cf56b8316d',
#     'lat': 34.037698,
#     'lon': -118.262404,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2a76bd93-2370-4cf0-a58f-3b1104f452df',
#     'lat': 34.045257,
#     'lon': -118.236058,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '115d993b-adeb-417c-a756-d0568c1491ca',
#     'lat': 34.025232,
#     'lon': -118.287183,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '7a7b6ee5-7fc9-41aa-9f3c-2a98a3755776',
#     'lat': 34.056676,
#     'lon': -118.391895,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '303f71f1-da83-4685-8dbc-ce1b2d5fd542',
#     'lat': 34.083687,
#     'lon': -118.356527,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '6d573478-bd5f-4d03-a2e0-9e4422fc7931',
#     'lat': 34.04869,
#     'lon': -118.235406,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'd916c9d9-2e5f-4aad-b448-d73bb374a246',
#     'lat': 34.021236,
#     'lon': -118.258179,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2bebded9-e979-4a3c-b4f9-f446cc420eaf',
#     'lat': 34.022244,
#     'lon': -118.291713,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '6010359a-fd03-437e-9bc4-b5d59987ba9f',
#     'lat': 34.112045,
#     'lon': -118.336279,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5d127114-2399-4424-822a-57ed4f6da4ba',
#     'lat': 33.99551424201019,
#     'lon': -118.462935118115,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a4793fdb-7720-41ad-bc6b-6cf6515eef6f',
#     'lat': 34.047935,
#     'lon': -118.258061,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'ca3307b9-5725-427d-b514-0498216da3da',
#     'lat': 34.02359,
#     'lon': -118.304762,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '1eaffbd0-29aa-409a-b7f8-45af392ff524',
#     'lat': 34.073163,
#     'lon': -118.387667,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '195b44e9-09ac-4d32-a787-123e4f43bd0d',
#     'lat': 34.100528,
#     'lon': -118.309278,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '7fbed25d-b48c-414f-b1c2-0f10ba5d5068',
#     'lat': 34.060861,
#     'lon': -118.445739,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '3546384d-893e-41b2-9fb5-170fb4550b5a',
#     'lat': 34.175,
#     'lon': -118.601971,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '7a8bc317-df14-4b52-a64b-220d36cb4ab5',
#     'lat': 34.04281,
#     'lon': -118.377004,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '20e69b78-a21d-419f-818f-2b79199b08fd',
#     'lat': 34.075619,
#     'lon': -118.439225,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '22ab2922-29c1-441f-8502-84d0a7a21eb3',
#     'lat': 34.049876,
#     'lon': -118.258738,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '08f67b02-f140-4238-94aa-d13aaf469544',
#     'lat': 34.06186,
#     'lon': -118.444195,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a5753f39-17a2-443c-b4da-e8b9ac8ce2a0',
#     'lat': 34.057586,
#     'lon': -118.351364,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2ffd4f0b-08c1-4c19-a0ff-39847df81fd9',
#     'lat': 34.083791,
#     'lon': -118.360367,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '46efb4a3-c078-4c76-b9b3-e751bf6530aa',
#     'lat': 34.068313,
#     'lon': -118.302953,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'cd00bc0b-9327-49da-98a3-a43c490a7598',
#     'lat': 34.059842,
#     'lon': -118.238123,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a1306ebd-7ea7-4afa-a683-7693f72d46e4',
#     'lat': 34.050377,
#     'lon': -118.459474,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '18c5a1cb-69bb-47c2-9c69-160ae6d8e023',
#     'lat': 34.067031,
#     'lon': -118.349901,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f208ba77-f871-4679-8be5-9678fa57fa7e',
#     'lat': 34.049042,
#     'lon': -118.461151,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '32b705d5-4891-49cb-bcd7-d62f2d49763e',
#     'lat': 34.05542,
#     'lon': -118.396623,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '172ba54b-a8c8-4c85-a746-1d413c881c52',
#     'lat': 34.054547,
#     'lon': -118.246337,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '403c9080-1698-4814-ade2-3c6f5e801593',
#     'lat': 34.04724,
#     'lon': -118.249875,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '3ffdc454-4f12-45b2-b166-60add89003ea',
#     'lat': 34.059177,
#     'lon': -118.378307,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5ee5b41c-ef10-479f-999f-3959745ccc51',
#     'lat': 34.017986666666665,
#     'lon': -118.29141999999999,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '83e07fbd-2ff7-4a36-8f67-37296498116b',
#     'lat': 34.039295,
#     'lon': -118.248208,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'e192ae9f-42cc-486e-9286-d9e30d43ccc0',
#     'lat': 34.063935,
#     'lon': -118.245863,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '30e39b1b-ef73-450e-94dd-1e8f99275174',
#     'lat': 34.082678,
#     'lon': -118.315762,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '08c534ce-18e4-4258-b3e9-888b0eb43ba6',
#     'lat': 34.069575,
#     'lon': -118.347786,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a9db3ce4-7c66-4c72-a05b-68b7858e27c2',
#     'lat': 34.082694,
#     'lon': -118.315691,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '811179f5-e36c-47cb-b088-b80e5bf65253',
#     'lat': 34.04627,
#     'lon': -118.266325,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '0d09a77a-1921-4a11-ae51-7b290da6f1fb',
#     'lat': 34.032119,
#     'lon': -118.458545,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '0d0e927a-d59b-42db-968c-a5319bfe0fc7',
#     'lat': 34.018436,
#     'lon': -118.310061,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '8eb111aa-d67f-4177-bf0b-79043f95cfb7',
#     'lat': 34.041535,
#     'lon': -118.265288,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '149c97af-4390-4656-8e26-455ec1ed796e',
#     'lat': 34.066313,
#     'lon': -118.2439,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '1b215269-30bb-4caf-8e8b-1f5bb655eecc',
#     'lat': 33.997255,
#     'lon': -118.467412,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'd245ee7d-5bf3-423e-877a-d3c3f18c10be',
#     'lat': 34.057582,
#     'lon': -118.2482,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '16e53423-b167-4a65-94d7-c9863a5bd22d',
#     'lat': 34.083904,
#     'lon': -118.372183,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '97a1d529-1ec6-4ac9-84cc-0640c6c5962a',
#     'lat': 34.065999,
#     'lon': -118.25456,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2402a3f2-e53c-467f-88d9-6bacf9829416',
#     'lat': 34.01477,
#     'lon': -118.334854,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'bf7efe72-542d-4871-897d-f75f4d901802',
#     'lat': 34.073617,
#     'lon': -118.259258,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'bbc24863-5c67-4ac1-a758-12b3a12f5b34',
#     'lat': 34.055903,
#     'lon': -118.396899,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '605b7207-54ec-483b-a45e-bce60f1366d1',
#     'lat': 34.049861,
#     'lon': -118.275068,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'aa8d6a4f-4f6a-417e-9bf1-c81ff13e1ab0',
#     'lat': 34.03442,
#     'lon': -118.264081,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '936f9ccb-5a5b-47d7-abc2-88ab91d2b728',
#     'lat': 34.038448,
#     'lon': -118.43244,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'c8add731-57cb-4e7d-896b-44cb1d465971',
#     'lat': 34.053533,
#     'lon': -118.250986,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '606e3953-02e5-474f-8f23-f3275bfbb669',
#     'lat': 33.990986,
#     'lon': -118.465972,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f423884c-c233-45e3-9ff2-595e9992c700',
#     'lat': 34.184756,
#     'lon': -118.577201,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5e8393eb-43d9-40c2-83e6-0049b7a5dd30',
#     'lat': 34.045208,
#     'lon': -118.256879,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b0af0e88-c448-4c5b-820a-a69ebf55bcc4',
#     'lat': 34.048076,
#     'lon': -118.23921,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '248e5663-2cd1-4164-bae5-e332164f9264',
#     'lat': 34.090642,
#     'lon': -118.324439,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a71ee6a3-4afb-45b8-86e1-fef99f02ec8f',
#     'lat': 34.061808,
#     'lon': -118.444292,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'd2794923-df89-4db1-9e02-b92e5a687820',
#     'lat': 34.018228,
#     'lon': -118.309282,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '0e1aa1e1-b199-439a-ad06-334f57a88e32',
#     'lat': 34.00247,
#     'lon': -118.426293,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'aebaa608-0d3a-4e71-899a-4878e3d3a294',
#     'lat': 34.203574,
#     'lon': -118.592782,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2c595883-142e-4efa-b97e-603f8ff9483d',
#     'lat': 34.073627,
#     'lon': -118.259114,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'd5aa4290-4aaf-45f6-8e03-3c41e5dad152',
#     'lat': 34.045282,
#     'lon': -118.257426,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '73eeed29-c264-4736-bd2f-021a28ce6fb8',
#     'lat': 34.076695,
#     'lon': -118.357368,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'dcc86ef3-e2e0-498d-9b07-bad0d95722aa',
#     'lat': 34.017002,
#     'lon': -118.278093,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'afd8b72a-064a-4297-a569-080722212c0a',
#     'lat': 34.055113,
#     'lon': -118.249463,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '973aeeae-dfcc-4dab-969b-e7b8f33e15ab',
#     'lat': 34.064478,
#     'lon': -118.45099,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f04d7ce5-a992-4425-af84-9386b37256e3',
#     'lat': 34.029246,
#     'lon': -118.41054,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '749fb715-0ba1-405d-abc7-e6ac6ae90721',
#     'lat': 34.070669,
#     'lon': -118.452561,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '7946e35a-9ea1-49d8-8446-4b34b59abf58',
#     'lat': 34.03715,
#     'lon': -118.450452,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b36f0ab4-5faf-4606-9c66-d226f97d1568',
#     'lat': 34.022566,
#     'lon': -118.336474,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '6b7ecc40-4525-4aac-b9c8-98e3113fdb0d',
#     'lat': 34.066272,
#     'lon': -118.358017,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '53610c73-93af-461d-898b-982b5d17fedd',
#     'lat': 34.03145,
#     'lon': -118.446036,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5d91ade8-7ba9-4631-89be-8653b03e2661',
#     'lat': 34.069368,
#     'lon': -118.449126,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '99695314-3180-4129-b0ab-5ae5a358a46d',
#     'lat': 34.044448,
#     'lon': -118.276771,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '58853354-665a-4491-b02a-5bf483f7983f',
#     'lat': 34.080434,
#     'lon': -118.36129,
#     'is_reserved': 0,
#     'is_disabled': 0},
# ...
#     'is_disabled': 0},
#    {'bike_id': '2d80e2f2-9a50-4658-99d9-837eee13a67f',
#     'lat': 34.049932,
#     'lon': -118.259377,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b330385a-8d68-4d98-8484-17ecd8082d99',
#     'lat': 34.083819,
#     'lon': -118.35862,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '15696648-56f9-49a5-8d94-b83e1bc62452',
#     'lat': 34.062291,
#     'lon': -118.447647,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2e1b2d35-4fd8-4cfa-97aa-a64d7968cced',
#     'lat': 34.04163,
#     'lon': -118.266475,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2bdd5068-5610-45b0-9f21-ecaf68846640',
#     'lat': 34.033456,
#     'lon': -118.270965,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'c465abe3-39c8-4b23-a2f9-f5c83d53e567',
#     'lat': 34.069895,
#     'lon': -118.445055,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '61406c66-1bcd-4778-8356-3a64e7f7bb41',
#     'lat': 34.036555,
#     'lon': -118.27798,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '061ccc4a-0083-4089-928e-6674609a761a',
#     'lat': 34.024001,
#     'lon': -118.285478,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5395fb36-9692-4264-acc3-d9a2d07bcc27',
#     'lat': 34.04595,
#     'lon': -118.258053,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a8e5fe56-a413-4bae-9406-e4d4346c6019',
#     'lat': 34.088975,
#     'lon': -118.214485,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'd0f1eda8-8512-4736-98e1-a4104c59f550',
#     'lat': 34.02211,
#     'lon': -118.280198,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'e718cfaa-8828-459b-a243-54558d356f1a',
#     'lat': 34.021385,
#     'lon': -118.412195,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '008e5fc6-4288-4712-972b-9e3caac63493',
#     'lat': 34.089605,
#     'lon': -118.276733,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a55f8188-acc0-4a72-b242-d2b5b6164fc2',
#     'lat': 34.024082,
#     'lon': -118.311996,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '8c88140c-7b2f-4820-9b4a-d29d7f179d74',
#     'lat': 34.054956,
#     'lon': -118.392206,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2fc3abdf-f82b-4079-b039-7c5f832ad4f7',
#     'lat': 34.051992,
#     'lon': -118.252017,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '0cbc142b-bf91-429b-974d-79916ffc6b64',
#     'lat': 34.103545,
#     'lon': -118.289488,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5edf2ea9-dcc9-4c2b-b08a-1e123aa1f3b1',
#     'lat': 34.033642,
#     'lon': -118.447446,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '1c243dcb-2eec-4b7f-8908-1fd8284175f5',
#     'lat': 34.064278231878255,
#     'lon': -118.31036217945469,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '7ce847ba-3e6d-4417-bf0d-f6b10deaf7c4',
#     'lat': 34.10382,
#     'lon': -118.32979,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '09b02419-2f54-4b6a-aba2-9b0448d52e46',
#     'lat': 33.999013,
#     'lon': -118.472161,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '1e629790-f2c1-4175-b04e-88d1fcb224c2',
#     'lat': 34.077395,
#     'lon': -118.263773,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b7104145-37c3-4ff1-ba07-7ab845067fbc',
#     'lat': 34.02205,
#     'lon': -118.376035,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'd32a2735-077c-4c40-ab56-600b272bf97e',
#     'lat': 34.103558,
#     'lon': -118.336876,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '6f779251-328d-4739-86fb-d750aef4f9a5',
#     'lat': 34.046295,
#     'lon': -118.45691,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '68a567c6-7659-4dc3-9da0-befe780e4832',
#     'lat': 34.02925,
#     'lon': -118.451306,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'ff4404b4-8421-48ab-9c40-01ada238c8bc',
#     'lat': 34.061973,
#     'lon': -118.433294,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5022999d-22d2-4765-a86a-8f44b29cbb9f',
#     'lat': 34.018559,
#     'lon': -118.291728,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f8b9f050-65e1-4e06-b480-91ed66a94cdc',
#     'lat': 34.026898,
#     'lon': -118.396095,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f2f04ecc-668d-469f-b235-f4a3efe49dbc',
#     'lat': 34.003273,
#     'lon': -118.433261,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '7b75564d-6ea4-4d99-ae5e-9a800c9cdc60',
#     'lat': 34.09823,
#     'lon': -118.341399,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '408cc66b-c8b9-4e8d-9ba7-5413db21dfa1',
#     'lat': 34.02708,
#     'lon': -118.270891,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '96f3e5bb-846d-4841-9568-6fd2bb13dbb1',
#     'lat': 34.070949,
#     'lon': -118.359129,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '9eac33c3-20ab-4e32-8257-04ca2883eb94',
#     'lat': 34.03747,
#     'lon': -118.250089,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b5a5cf38-ba72-49a8-adfe-100aa9c0654b',
#     'lat': 34.038088,
#     'lon': -118.263258,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '45836c51-9524-4158-b55a-26a5406ebf31',
#     'lat': 34.094772,
#     'lon': -118.344162,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '712e1f66-df59-44ec-bf6d-6765cc0bc7a2',
#     'lat': 34.045798,
#     'lon': -118.258053,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '70a2f590-252f-4a4b-84da-5c0bbafd4826',
#     'lat': 34.055385,
#     'lon': -118.262664,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5895a8c2-1534-4ad9-bd07-a4afdfca72da',
#     'lat': 34.107556,
#     'lon': -118.254725,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '4b8b7e26-c8c3-4d3b-8d2e-bf3e07ee7d2e',
#     'lat': 34.098127,
#     'lon': -118.338049,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '228ca5bc-fdb5-4656-a3f1-c4114e1ad163',
#     'lat': 34.030031,
#     'lon': -118.387781,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '9d7dd3b1-446e-45f4-825e-c2f94b6546c7',
#     'lat': 34.073085,
#     'lon': -118.373114,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2eed8808-9112-44e2-a962-e607d1b76ccb',
#     'lat': 34.066308,
#     'lon': -118.4475,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '568ff7cb-33bd-43b1-9c03-0ac54087810b',
#     'lat': 34.023917,
#     'lon': -118.28375,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'dadd92a5-7089-4a8d-90dd-dab8daff0cd0',
#     'lat': 34.101799,
#     'lon': -118.309397,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '72e79b95-b280-440a-964f-3d0340a6cae3',
#     'lat': 34.263608,
#     'lon': -118.522124,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f9653bd4-de48-40d3-924e-b0fcd88f7b08',
#     'lat': 34.06321,
#     'lon': -118.369759,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '49f0933a-e5ef-46a5-9ecb-17a820e193a3',
#     'lat': 34.06184333333333,
#     'lon': -118.44402333333333,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'c9294adf-4164-4b5c-82f9-525ddb79828d',
#     'lat': 34.070382,
#     'lon': -118.352931,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '09465665-35e9-4279-aec1-f80d8b184877',
#     'lat': 34.037378,
#     'lon': -118.454068,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a4f91700-78c3-40ac-b64c-10fdb440d16c',
#     'lat': 34.091055,
#     'lon': -118.283883,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'c95c9df5-5234-4315-9f31-34e3b98dd62a',
#     'lat': 34.053545,
#     'lon': -118.249349,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '984142d0-87ff-4755-860a-b8bb6092168f',
#     'lat': 34.098218,
#     'lon': -118.286932,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '792ac1de-d308-4dc6-8ee6-cbd71b1e2a4c',
#     'lat': 34.023864,
#     'lon': -118.283792,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'c9793b29-312b-4883-81db-3175c0c2e9c9',
#     'lat': 34.00877,
#     'lon': -118.27035499999998,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'e315b0c6-1464-43b5-abe4-9618abaedfe5',
#     'lat': 34.068908,
#     'lon': -118.447598,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b7795d21-4df2-4d83-bef4-065cdf0c3942',
#     'lat': 34.02024,
#     'lon': -118.280914,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '57fe102f-e1cd-4a96-938b-2d10f4a79dec',
#     'lat': 34.072122,
#     'lon': -118.366453,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '0293b66f-2d0b-4b8b-abf1-70b5eb37637b',
#     'lat': 34.081033,
#     'lon': -118.356292,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '456a1b63-3fb4-42ea-b187-099bec92797e',
#     'lat': 34.098634,
#     'lon': -118.322409,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'af9792a4-1e4e-4ea8-b2b6-01a974a9ba8d',
#     'lat': 34.061149,
#     'lon': -118.440603,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f82debba-3693-4e50-8c25-46d895cd35e9',
#     'lat': 34.050774,
#     'lon': -118.24368,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2d2d79b3-656c-4281-bdf3-797d824fb489',
#     'lat': 34.001236,
#     'lon': -118.461239,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '9f4425b9-7add-442a-a05a-8867a94630df',
#     'lat': 34.062384,
#     'lon': -118.307847,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '6e6bb3a8-22b5-487c-b661-8a24a848142e',
#     'lat': 34.036135,
#     'lon': -118.455449,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '9d60ba61-33fc-493c-93b6-81dff3b31e8c',
#     'lat': 34.060275,
#     'lon': -118.419294,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '63a12cad-d173-4b36-a661-feafa661a360',
#     'lat': 34.066619,
#     'lon': -118.447284,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'e402f0a6-5bdb-4d2e-b794-1916f206e3c6',
#     'lat': 34.048163,
#     'lon': -118.244918,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '0afd5774-8060-4168-a307-33103abe599c',
#     'lat': 34.038395,
#     'lon': -118.263154,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '25c69dd9-5525-4103-911d-d199ea67fe35',
#     'lat': 34.061806,
#     'lon': -118.444378,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '9751701b-8836-4e14-8bb4-cba6f8c07294',
#     'lat': 34.19023,
#     'lon': -118.457586,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '12a4f526-f255-4ce4-9f43-5cca7c6012ba',
#     'lat': 34.070375,
#     'lon': -118.35299,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '41ccd6d0-04fa-4d93-a215-9aef674f6c55',
#     'lat': 34.055058333333335,
#     'lon': -118.28849,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f89de45a-ea8f-4477-b305-14498c4baa0c',
#     'lat': 34.063091,
#     'lon': -118.354611,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5f997179-997b-4412-8481-958b834b5192',
#     'lat': 34.087777,
#     'lon': -118.346185,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'eb8160fc-2e50-4a47-a01c-58760c69bad7',
#     'lat': 34.015875,
#     'lon': -118.277451,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'c9bb0baa-6426-4647-a3a7-bad64668cb16',
#     'lat': 34.05982,
#     'lon': -118.279378,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '8769bc28-bfc9-4c84-84f4-994cf1e97e41',
#     'lat': 34.022784,
#     'lon': -118.282191,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'fad4978a-8567-4ed4-883f-b75af6aa3f17',
#     'lat': 34.06942,
#     'lon': -118.453727,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '92fa9597-b3ab-4070-b92a-439599771f26',
#     'lat': 34.047666,
#     'lon': -118.257579,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '076283f2-1c7e-4d91-8ecf-ea7a5816713e',
#     'lat': 34.037259,
#     'lon': -118.270374,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '16381246-9e73-48c8-8efb-fcdc6b1f5547',
#     'lat': 34.03497,
#     'lon': -118.265603,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '6e0fecae-1aa5-48fd-bdbd-13d76cda3362',
#     'lat': 34.112003,
#     'lon': -118.336278,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '455ecc63-0546-4c2f-8085-3f015279de79',
#     'lat': 34.030277,
#     'lon': -118.262955,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '06aa16f5-e479-4f4e-b8e7-01ee7ebdba0a',
#     'lat': 34.104188,
#     'lon': -118.338006,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'a8979d1a-9444-4812-8d23-df04720bdf4f',
#     'lat': 34.043407,
#     'lon': -118.236426,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'eb7f5c1c-831a-4f42-a865-e470c5c8657a',
#     'lat': 34.049406,
#     'lon': -118.238049,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'df73cd69-71fc-41a5-a4da-eaa40d4a5312',
#     'lat': 34.074968,
#     'lon': -118.453826,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '9fa1a60d-21a3-4a70-a54c-014f35752e83',
#     'lat': 34.04490333333333,
#     'lon': -118.47193166666666,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '801397cd-333f-4eef-886a-bc5cc72b7d03',
#     'lat': 34.071406,
#     'lon': -118.377089,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'c043e1fc-613e-4e1b-a2f1-036443e76451',
#     'lat': 34.098152,
#     'lon': -118.293257,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'f8a3a136-9f94-4a2d-9c92-322fae24f85d',
#     'lat': 34.179014,
#     'lon': -118.590619,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '121953e9-3f17-4576-b854-347d75581846',
#     'lat': 34.101626,
#     'lon': -118.319273,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '4e4978f1-5255-4e6c-abce-b55e7357704c',
#     'lat': 34.04844,
#     'lon': -118.24483,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '991a4868-2e7b-4447-8a2c-9eb7c2c8885f',
#     'lat': 34.045929,
#     'lon': -118.257885,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'b144ca4b-79e0-4a44-818c-077af003efa4',
#     'lat': 34.086695,
#     'lon': -118.342772,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'd758bb0b-ea82-4ee9-b08b-ec2066e13a1b',
#     'lat': 34.048479,
#     'lon': -118.235083,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '329171b9-184c-4740-9148-dd11414b28c7',
#     'lat': 33.990417,
#     'lon': -118.465051,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '5a6e7c57-7828-44fc-a21d-6a17a6ed010f',
#     'lat': 34.03102,
#     'lon': -118.2715,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'c2c735da-ddd6-483a-b82b-15687f3f87bf',
#     'lat': 34.048899,
#     'lon': -118.258318,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '1df36c9e-cf26-4bac-8bba-790b605a6df8',
#     'lat': 34.048632,
#     'lon': -118.337188,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'e42afb28-01bb-4f0c-88df-e81e477be5f7',
#     'lat': 34.046505,
#     'lon': -118.255724,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '79961b40-394d-4789-a8a8-b6a7b2606a55',
#     'lat': 34.042273,
#     'lon': -118.206521,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '2ab060f3-ca2e-4bde-92d3-aec8c6c9048c',
#     'lat': 34.068954,
#     'lon': -118.445506,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'd2419105-e6f3-428a-aad4-938fd989a265',
#     'lat': 34.10195,
#     'lon': -118.338278,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '195ea77f-188c-49bc-b307-31d9d6800a77',
#     'lat': 34.061747,
#     'lon': -118.309048,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '6856eaca-b17b-48f8-9cbc-3d6a6b4fa11c',
#     'lat': 34.089764,
#     'lon': -118.276964,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': '77d75e6e-bc0a-43b5-80ba-9425d2993095',
#     'lat': 34.04425,
#     'lon': -118.262992,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    {'bike_id': 'aa422752-a28a-43c4-9e3a-a282331cf24d',
#     'lat': 34.067851,
#     'lon': -118.453769,
#     'is_reserved': 0,
#     'is_disabled': 0},
#    ...]},
#  'ttl': 60}

# %% [markdown]
# ## Data Wrangling, Part 1
# For today's exercises, we are going to be working with data using Python's `pandas` package. We will start with how to read in CSV data, then how to combine multiple dataframes into one. We will then move on to learning about how to calculate summary statistics, join data from different dataframes, and produce a summary extract for export.
#
# ### Exercise 1: Importing & Concatenating Data in Pandas
# Yesterday we prepared a series of CSV file extracts containing Metro vehicle location data and saved them to disk. Today we will learn how to read in CSV files using `pandas.read_csv()` instead of the `csv` package. We will then combine multiple dataframes into one dataframe.

# %%
import os

path = 'output'

try:
    os.mkdir(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)
# Out:
# Successfully created the directory output

# %%
# Import libraries (pandas)
import pandas as pd

# TODO: Add the paths to any two of your CSV files from yesterday
filepath_1 = 'day2-prj/data/raw/lametro_10_2019-09-16-15-46-54.csv'
filepath_2 = 'day2-prj/data/raw/lametro_710_2019-09-16-15-49-56.csv'

# TODO: Read both CSVs like this -> pd.read_csv(filepath)
metro_df1 = pd.read_csv(filepath_1)
metro_df2 = pd.read_csv(filepath_2)

# Here is how we get the number of rows in a dataframe
print(len(metro_df1))
print(len(metro_df2))
# Out:
# 12
# 10

# %% [markdown]
# Two dataframes with the same columns can be combined using [pd.concat](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html). Let's give it a try.

# %%
# Concatenate the dataframes
metro_df = pd.concat([metro_df1, metro_df2])

# TODO: Print the length of the new combined dataframe
print(len(metro_df))
# Out:
# 22

# %% [markdown]
# We've certainly cut down on the amount of code by moving to `pd.read_csv()`. However, do we still need to write out every filepath and read each one in individually? What if we built a loop to read through all of our files and append them together automatically?
#
# Let's take a stab at it. We are going to use Python's [glob](https://docs.python.org/3/library/glob.html) package to search for all of our la metro data extracts.

# %%
import glob

# This handy statement will get us a list of filenames
all_filenames = [i for i in glob.glob('day2-prj/data/raw/lametro*.csv')]

# Create an empty list that will hold our dataframes
df_list = []

# TODO: Loop through all of our `all_filenames`, read_csv to convert to a dataframe, then append the df to df_list
for filename in all_filenames:
    metro_df_i = pd.read_csv(filename)
    print(metro_df_i.shape)
#     print(filename)
    df_list.append(metro_df_i)

# TODO: Concatenate all the dataframes together
# metro_df_all = pd.concat(df_list)
# Out:
# (6, 9)
# (6, 9)
# (5, 9)
# (5, 9)
# (5, 9)
# (8, 9)
# (8, 9)
# (9, 9)
# (7, 9)
# (8, 9)
# (17, 9)
# (18, 9)
# (20, 9)
# (21, 9)
# (20, 9)
# (8, 9)
# (7, 9)
# (6, 9)
# (6, 9)
# (6, 9)

# %%
len(df_list)
# Out:
# 20

# %%
metro_df_all = pd.concat(df_list)
metro_df_all.head()
# Out:
#    heading    id   latitude   longitude  predictable  route_id    run_id  \
# 0    220.0  3878  34.086086 -118.382164         True      10.0  10_546_0
# 1    125.0  6016  34.066203 -118.254197         True      10.0  10_546_0
# 2    269.0  5721  34.083570 -118.323574         True      10.0  10_533_1
# 3    165.0  5839  34.081272 -118.284447         True      10.0  10_549_0
# 4     38.0  6139  34.051544 -118.249184         True      10.0  10_533_1
#
#    seconds_since_report                   call_time
# 0                   217  2019-09-17 11:23:28.227052
# 1                    18  2019-09-17 11:23:28.227052
# 2                    19  2019-09-17 11:23:28.227052
# 3                    16  2019-09-17 11:23:28.227052
# 4                   157  2019-09-17 11:23:28.227052

# %%
metro_df_all.dropna(subset=['route_id'], inplace=True)

# %%
# Let's see how many rows we have in our new SUPER DATAFRAME
print(len(metro_df_all))
# Out:
# 195

# %% [markdown]
# ### Exercise 2: Summarize Collision Data (Fatalities by Year)
#  The [Los Angeles Vision Zero Safety Study](https://view.joomag.com/vision-zero-safety-study/0065798001485405769?short), published in January 2017, provides insights about collisions in the City using data from 2009-2013. Let's attempt to replicate some the analysis, which will allow us to begin answering questions such as these: Are we making progress towards that goal? If not, how far behind are we?
#
# ##### Prep
# Let's start by reading in the CSV files for collision data.

# %%
# TODO: Import each of the three tables
import pandas as pd

collisions = pd.read_csv('data/raw/Collisions_20092013_SWITRS.csv')
parties = pd.read_csv('data/raw/Party_Tables__Collisions_20092013_SWITRS.csv')
victims = pd.read_csv('data/raw/Victim_Tables__Collisions_20092013_SWITRS.csv')

# %% [markdown]
# Let's take a peek at the data we just imported. It is a good habit to build to constantly check the data as you move it through the wrangling process to make sure that it is not getting transformed in unexpected ways. We can take a look at the first couple of rows of a dataframe by using Pandas' [df.head()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html) method.

# %%
# Examine the 'head' of the collision table
collisions.head()
# Out:
#             X          Y  OBJECTID  CASE_ID  ACCIDENT_YEAR  \
# 0 -118.320580  33.989071      4001  4127182           2009
# 1 -118.262935  34.044239      4002  4127195           2009
# 2 -118.254034  34.084091      4003  4127211           2009
# 3 -118.177198  34.079670      4004  4127215           2009
# 4 -118.257480  34.050159      4005  4127220           2009
#
#                    PROCDATE  JURIS            COLLISION_DATE  COLLISION_TIME  \
# 0  2009-08-22T00:00:00.000Z   1942  2009-01-29T00:00:00.000Z            1215
# 1  2009-08-25T00:00:00.000Z   1942  2009-01-23T00:00:00.000Z            1320
# 2  2009-09-08T00:00:00.000Z   1942  2009-01-17T00:00:00.000Z            1250
# 3  2009-09-09T00:00:00.000Z   1942  2009-01-27T00:00:00.000Z             305
# 4  2009-09-08T00:00:00.000Z   1942  2009-01-30T00:00:00.000Z            1400
#
#   OFFICER_ID  ... TIMECAT  MONTH_         CITY       COUNTY  STATE  \
# 0      39053  ...    1500       1  LOS ANGELES  LOS ANGELES     CA
# 1      37506  ...    1500       1  LOS ANGELES  LOS ANGELES     CA
# 2      37506  ...    1500       1  LOS ANGELES  LOS ANGELES     CA
# 3      36814  ...     600       1  LOS ANGELES  LOS ANGELES     CA
# 4      39163  ...    1500       1  LOS ANGELES  LOS ANGELES     CA
#
#       POINT_X    POINT_Y                                         Match_addr  \
# 0 -118.320580  33.989071    W SLAUSON AVE & 3RD AVE, LOS ANGELES, CA, 90043
# 1 -118.262935  34.044239  S FLOWER ST & W OLYMPIC BLVD, LOS ANGELES, CA,...
# 2 -118.254034  34.084091   ECHO PARK AVE & EFFIE ST, LOS ANGELES, CA, 90026
# 3 -118.177198  34.079670  PHELPS AVE & LYNNFIELD ST, LOS ANGELES, CA, 90032
# 4 -118.257480  34.050159     W 6TH ST & S FLOWER ST, LOS ANGELES, CA, 90017
#
#      m_primaryrd      m_secondrd
# 0  W SLAUSON AVE         3RD AVE
# 1    S FLOWER ST  W OLYMPIC BLVD
# 2  ECHO PARK AVE        EFFIE ST
# 3     PHELPS AVE    LYNNFIELD ST
# 4       W 6TH ST     S FLOWER ST
#
# [5 rows x 89 columns]

# %% [markdown]
# What do all of these feature values represent? You can take a look at the [SWITRS Codebook](https://peteraldhous.com/Data/ca_traffic/SWITRS_codebook.pdf), which will explain each variable in all three of our tables.

# %%
# Alternatively, we can look at the 'tail' of the table by running the code below
parties.tail()
# Out:
#         OBJECTID  CASE_ID  PARTY_NUMBER  PARTY_TYPE AT_FAULT PARTY_SEX  \
# 937667    936996  9018771             1         1.0        Y         M
# 937668    936997  9018771             2         1.0        N         M
# 937669    936998  9018771             3         1.0        N         M
# 937670    936999  9018771             4         1.0        N         F
# 937671    937000  9018773             1         1.0        Y         M
#
#         PARTY_AGE PARTY_SOBRIETY PARTY_DRUG_PHYSICAL DIR_OF_TRAVEL  ...  \
# 937667         19              B                   -             S  ...
# 937668         50              A                   -             S  ...
# 937669         58              A                   -             N  ...
# 937670         57              A                   -             N  ...
# 937671         40              A                   -             W  ...
#
#        VEHICLE_YEAR VEHICLE_MAKE STWD_VEHICLE_TYPE CHP_VEH_TYPE_TOWING  \
# 937667       2002.0       NISSAN                 -                   -
# 937668       1987.0    CHEVROLET                 -                   -
# 937669       2005.0        HONDA                 -                   -
# 937670       1998.0      MERCURY                 -                   -
# 937671       2004.0         FORD                 -                   -
#
#        CHP_VEH_TYPE_TOWED RACE INATTENTION SPECIAL_INFO_F  SPECIAL_INFO_G  \
# 937667                 00    O         NaN              -               -
# 937668                 00    W         NaN              -               -
# 937669                 00    W         NaN              -               -
# 937670                 00    B         NaN              -               -
# 937671                 00    W         NaN              -               -
#
#        ACCIDENT_YEAR
# 937667          2006
# 937668          2006
# 937669          2006
# 937670          2006
# 937671          2006
#
# [5 rows x 35 columns]

# %%
 # TODO: Change the size of the head to show the top 15 rows (see documentation above)
parties.head(15)
# Out:
#     OBJECTID  CASE_ID  PARTY_NUMBER  PARTY_TYPE AT_FAULT PARTY_SEX  PARTY_AGE  \
# 0       9001   670821             1         1.0        Y         M         39
# 1       9002   670823             1         1.0        Y         F         22
# 2       9003   670823             2         1.0        N         M         22
# 3       9004   670824             1         1.0        Y         -        998
# 4       9005   670824             2         1.0        N         F         68
# 5       9006   670825             1         1.0        Y         -        998
# 6       9007   670825             2         2.0        N         F         16
# 7       9008   670825             3         2.0        N         F         17
# 8       9009   670825             4         2.0        N         F         15
# 9       9010   670826             1         1.0        N         M         67
# 10      9011   670826             2         2.0        N         F         17
# 11      9012   670827             1         1.0        Y         M         39
# 12      9013   670827             2         1.0        N         M         41
# 13      9014   670828             1         1.0        Y         -        998
# 14      9015   670828             2         3.0        N         -        998
#
#    PARTY_SOBRIETY PARTY_DRUG_PHYSICAL DIR_OF_TRAVEL  ... VEHICLE_YEAR  \
# 0               A                   -             W  ...       2002.0
# 1               A                   -             S  ...       1997.0
# 2               A                   -             W  ...       1986.0
# 3               G                   G             W  ...          0.0
# 4               A                   -             N  ...       1994.0
# 5               G                   G             N  ...          0.0
# 6               A                   -             W  ...          0.0
# 7               A                   -             W  ...          0.0
# 8               A                   -             W  ...          0.0
# 9               A                   -             E  ...       2001.0
# 10              A                   -             S  ...          0.0
# 11              A                   -             S  ...       1992.0
# 12              A                   -             W  ...       1991.0
# 13              G                   G             -  ...          0.0
# 14              A                   -             -  ...       1998.0
#
#     VEHICLE_MAKE STWD_VEHICLE_TYPE CHP_VEH_TYPE_TOWING CHP_VEH_TYPE_TOWED  \
# 0          LEXUS                 A                 NaN                NaN
# 1           FORD                 A                 NaN                NaN
# 2          HONDA                 A                 NaN                NaN
# 3              -                 A                 NaN                NaN
# 4          MAZDA                 A                 NaN                NaN
# 5   OTHER - AUTO                 A                 NaN                NaN
# 6              -                 N                 NaN                NaN
# 7              -                 N                 NaN                NaN
# 8              -                 N                 NaN                NaN
# 9      CHEVROLET                 A                 NaN                NaN
# 10             -                 N                 NaN                NaN
# 11           BMW                 A                 NaN                NaN
# 12         DODGE                 A                 NaN                NaN
# 13             -                 A                 NaN                NaN
# 14      CADILLAC                 A                 NaN                NaN
#
#    RACE INATTENTION SPECIAL_INFO_F  SPECIAL_INFO_G ACCIDENT_YEAR
# 0     H         NaN              -               -          2003
# 1     H         NaN              -               -          2003
# 2     H         NaN              -               -          2003
# 3   NaN         NaN              -               -          2003
# 4     O         NaN              -               -          2003
# 5   NaN         NaN              -               -          2003
# 6     H         NaN              -               -          2003
# 7     H         NaN              -               -          2003
# 8     H         NaN              -               -          2003
# 9     W         NaN              -               -          2003
# 10    W         NaN              -               -          2003
# 11    H         NaN              -               -          2003
# 12    H         NaN              -               -          2003
# 13  NaN           -              -               -          2003
# 14  NaN         NaN              -               -          2003
#
# [15 rows x 35 columns]

# %% [markdown]
# When we are accessing really WIDE tables like the ones above, the `df.head()` method won't show us all the column names. We can access the column names by calling `df.columns` to get the list of all columns in the table. Access the [SWITRS Codebook](https://peteraldhous.com/Data/ca_traffic/SWITRS_codebook.pdf) for detail on what all these column values represent.

# %%
# TODO: Print the column names for the collisions table
collisions.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'CASE_ID', 'ACCIDENT_YEAR', 'PROCDATE', 'JURIS',
#        'COLLISION_DATE', 'COLLISION_TIME', 'OFFICER_ID', 'REPORTING_DISTRICT',
#        'DAY_OF_WEEK', 'SHIFT', 'POPULATION', 'CNTY_CITY_LOC', 'SPECIAL_COND',
#        'BEAT_TYPE', 'CHP_BEAT_TYPE', 'CITY_DIVISION_LAPD', 'CHP_BEAT_CLASS',
#        'BEATNUMB', 'PRIMARY_RD', 'SECONDARY_RD', 'DISTANCE', 'DIRECTION',
#        'INTERSECTION', 'WEATHER_1', 'WEATHER_2', 'STATE_HWY_IND',
#        'CALTRANS_COUNTY', 'CALTRANS_DISTRICT', 'STATE_ROUTE', 'ROUTE_SUFFIX',
#        'POSTMILE_PREFIX', 'POSTMILE', 'LOCATION_TYPE', 'RAMP_INTERSECTION',
#        'SIDE_OF_HWY', 'TOW_AWAY', 'COLLISION_SEVERITY', 'NUMBER_KILLED',
#        'NUMBER_INJURED', 'PARTY_COUNT', 'PRIMARY_COLL_FACTOR', 'PCF_CODE_VIOL',
#        'PCF_VIOL_CATEGORY', 'PCF_VIOLATION', 'PCF_VIOL_SUBSECTION',
#        'HIT_AND_RUN', 'TYPE_OF_COLLISION', 'MVIW', 'PED_ACTION',
#        'ROAD_SURFACE', 'ROAD_COND_1', 'ROAD_COND_2', 'LIGHTING',
#        'CONTROL_DEVICE', 'CHP_ROAD_TYPE', 'PEDESTRIAN_ACCIDENT',
#        'BICYCLE_ACCIDENT', 'MOTORCYCLE_ACCIDENT', 'TRUCK_ACCIDENT',
#        'NOT_PRIVATE_PROPERTY', 'ALCOHOL_INVOLVED', 'STWD_VEHTYPE_AT_FAULT',
#        'CHP_VEHTYPE_AT_FAULT', 'COUNT_SEVERE_INJ', 'COUNT_VISIBLE_INJ',
#        'COUNT_COMPLAIN_PAIN', 'COUNT_PED_KILLED', 'COUNT_PED_INJURED',
#        'COUNT_BICYCLIST_KILLED', 'COUNT_BICYCLIST_INJURED', 'COUNT_MC_KILLED',
#        'COUNT_MC_INJURED', 'PRIMARY_RAMP', 'SECONDARY_RAMP', 'LATITUDE',
#        'LONGITUDE', 'TIMECAT', 'MONTH_', 'CITY', 'COUNTY', 'STATE', 'POINT_X',
#        'POINT_Y', 'Match_addr', 'm_primaryrd', 'm_secondrd'],
#       dtype='object')

# %% [markdown]
# How many rows are in each dataset? For each of the tables, print out the following: `The number of rows in the [table name] is [number of rows]`. For example: `The number of rows in the collision table is 1200`.

# %%
# TODO: Print out the number of rows for each of the three datafram



for table_name in [collisions, parties, victims]:
    row_count = table_name.shape[0]
    print(row_count)

print(f'The number of rows in the collision table is {collisions.shape[0]}')
print(f'The number of rows in the party table is {parties.shape[0]}')
print(f'The number of rows in the victim table is {victims.shape[0]}')
# Out:
# 173714
# 937672
# 576617
# The number of rows in the collision table is 173714
# The number of rows in the party table is 937672
# The number of rows in the victim table is 576617

# %% [markdown]
# ##### Step 1: Filter for fatalities
# The first step to summarazing fatalites by year is to employ a row-based filter to our data.

# %%
# TODO: Filter for only collisions
fatal_collisions = collisions[collisions['COLLISION_SEVERITY'] == 1]

# %%
len(collisions.query('COLLISION_SEVERITY == 1'))
# Out:
# 875

# %% [markdown]
# How many fatal collisions occurred between 2009 and 2013?

# %%
# TODO: Print out the number of fatal collisions (Hint: It is the rowcount, since we filtered for only fatal collisions)
fatal_collisions.shape[0]
# Out:
# 875

# %% [markdown]
# ##### Step 2: Count fatalities by year
# An important distinction to be aware of when reading the report and replicating the findings is whether the statistic refers to _collisons_ or to _victims_ since this will determine which table we will be working with. In this case, since we are benchmarking our progress against the goal of zero _fatalities_ we will be looking at the victim table.

# %%
victims.columns
# Out:
# Index(['OBJECTID', 'CASE_ID', 'PARTY_NUMBER', 'VICTIM_ROLE', 'VICTIM_SEX',
#        'VICTIM_AGE', 'VICTIM_DEGREE_OF_INJURY', 'VICTIM_SEATING_POSITION',
#        'VICTIM_SAFETY_EQUIP_1', 'VICTIM_SAFETY_EQUIP_2', 'VICTIM_EJECTED',
#        'ACCIDENT_YEAR'],
#       dtype='object')

# %%
# TODO: Within fatal_collisions, group by year and count
fatalities_victim = victims[victims['VICTIM_DEGREE_OF_INJURY'] == 1]

fatalities_by_year = fatalities_victim.ACCIDENT_YEAR.value_counts().sort_index()

# Let's take a look
print(fatalities_by_year)
# Out:
# 2003    242
# 2004    221
# 2005    203
# 2006    227
# 2007    210
# 2008    227
# 2009    181
# 2010    184
# 2011    157
# 2012    200
# 2013    201
# 2014    196
# Name: ACCIDENT_YEAR, dtype: int64

# %% [markdown]
# ### Exercise 3: Prepare and Export a Custom Data Extract
# While the Jupyter notebook is in most cases the ideal place to explore and present data, we occassionaly want to be able to export data or findings for use elsewhere. After we take a look at the trends for traffic fatalities, we are going to prepare a custom data extract.
#
# It is not uncommon for policymakers to want to know more specific information for those who have been killed in a traffic collision. Let's pretend the Mayor has asked for a list of all fatalities in the year 2013 with the following information for each fatality:
# 1. Date & time of collision - Collision Table
# 2. Type of collision (Head-On, Sideswipe, etc.) - Collision Table
# 3. Whether Alcohol was involved (yes/no) - Collision Table
# 4. Age of the victim - Victim Table
# 5. Victim's mode of transportation - Victim Table
# 6. Distance of the collision from the intersection (to know whether it was intersection-related) - Collision Table
#
# Let's produce this data extract.

# %% [markdown]
# ##### Step 1: Filter for 2013 fatalities
# We can begin this assignment by noting that we are only interested in fatalities within 2013. We will therefore be applying 2 filters:
# - Year = 2013 and
# - Victim Degree of Injury = 1 (fatal)

# %%
# TODO: Filter for 2013 victims
victims_2013 = victims[victims['ACCIDENT_YEAR'] == 2013]

# TODO: Filter 2013 fatal victims 
fatal_victims_2013 = victims_2013[victims_2013['VICTIM_DEGREE_OF_INJURY'] == 1]

# Examine what's left
fatal_victims_2013.head()
# Out:
#         OBJECTID  CASE_ID  PARTY_NUMBER  VICTIM_ROLE VICTIM_SEX  VICTIM_AGE  \
# 495785    498786  5946386             2            3          M          50
# 496320    496321  5639079             2            3          M          55
# 496321    496322  5639091             2            3          M          23
# 496322    496323  5639301             1            1          F          44
# 496323    496324  5639357             1            1          M          29
#
#         VICTIM_DEGREE_OF_INJURY  VICTIM_SEATING_POSITION  \
# 495785                        1                      9.0
# 496320                        1                      9.0
# 496321                        1                      9.0
# 496322                        1                      1.0
# 496323                        1                      1.0
#
#        VICTIM_SAFETY_EQUIP_1 VICTIM_SAFETY_EQUIP_2  VICTIM_EJECTED  \
# 495785                     -                     -             3.0
# 496320                     -                     -             3.0
# 496321                     -                     -             3.0
# 496322                     L                     H             0.0
# 496323                     P                     W             1.0
#
#         ACCIDENT_YEAR
# 495785           2013
# 496320           2013
# 496321           2013
# 496322           2013
# 496323           2013

# %% [markdown]
# How many fatalities were in 2013? How is this number different from the count of fatal _collisions?_

# %%
# TODO: Print out the number of total number of victims of fatal injury for 2013 
fatal_victims_2013.shape[0]
# Out:
# 201

# %%
fatal_collisions_2013 = fatal_collisions[fatal_collisions['ACCIDENT_YEAR'] == 2013]
fatal_collisions_2013.shape[0]
# Out:
# 190

# %% [markdown]
# ##### Step 2: Join tables
# Looking through the SWITRS Codebook, you will notice that these data are not contained within a single table - instead we are going to need to join at least 2 tables to produce the necessary information. For each of the requested fields, find it in the codebook to determine the table the field resides in; you will then want to make an **_inner join_** (see [here](http://www.khankennels.com/blog/index.php/archives/2007/04/20/getting-joins/) for a summary of join types) with the currently filtered fatalies data.
#
# ![joins](join_types.png)

# %%
collisions.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'CASE_ID', 'ACCIDENT_YEAR', 'PROCDATE', 'JURIS',
#        'COLLISION_DATE', 'COLLISION_TIME', 'OFFICER_ID', 'REPORTING_DISTRICT',
#        'DAY_OF_WEEK', 'SHIFT', 'POPULATION', 'CNTY_CITY_LOC', 'SPECIAL_COND',
#        'BEAT_TYPE', 'CHP_BEAT_TYPE', 'CITY_DIVISION_LAPD', 'CHP_BEAT_CLASS',
#        'BEATNUMB', 'PRIMARY_RD', 'SECONDARY_RD', 'DISTANCE', 'DIRECTION',
#        'INTERSECTION', 'WEATHER_1', 'WEATHER_2', 'STATE_HWY_IND',
#        'CALTRANS_COUNTY', 'CALTRANS_DISTRICT', 'STATE_ROUTE', 'ROUTE_SUFFIX',
#        'POSTMILE_PREFIX', 'POSTMILE', 'LOCATION_TYPE', 'RAMP_INTERSECTION',
#        'SIDE_OF_HWY', 'TOW_AWAY', 'COLLISION_SEVERITY', 'NUMBER_KILLED',
#        'NUMBER_INJURED', 'PARTY_COUNT', 'PRIMARY_COLL_FACTOR', 'PCF_CODE_VIOL',
#        'PCF_VIOL_CATEGORY', 'PCF_VIOLATION', 'PCF_VIOL_SUBSECTION',
#        'HIT_AND_RUN', 'TYPE_OF_COLLISION', 'MVIW', 'PED_ACTION',
#        'ROAD_SURFACE', 'ROAD_COND_1', 'ROAD_COND_2', 'LIGHTING',
#        'CONTROL_DEVICE', 'CHP_ROAD_TYPE', 'PEDESTRIAN_ACCIDENT',
#        'BICYCLE_ACCIDENT', 'MOTORCYCLE_ACCIDENT', 'TRUCK_ACCIDENT',
#        'NOT_PRIVATE_PROPERTY', 'ALCOHOL_INVOLVED', 'STWD_VEHTYPE_AT_FAULT',
#        'CHP_VEHTYPE_AT_FAULT', 'COUNT_SEVERE_INJ', 'COUNT_VISIBLE_INJ',
#        'COUNT_COMPLAIN_PAIN', 'COUNT_PED_KILLED', 'COUNT_PED_INJURED',
#        'COUNT_BICYCLIST_KILLED', 'COUNT_BICYCLIST_INJURED', 'COUNT_MC_KILLED',
#        'COUNT_MC_INJURED', 'PRIMARY_RAMP', 'SECONDARY_RAMP', 'LATITUDE',
#        'LONGITUDE', 'TIMECAT', 'MONTH_', 'CITY', 'COUNTY', 'STATE', 'POINT_X',
#        'POINT_Y', 'Match_addr', 'm_primaryrd', 'm_secondrd'],
#       dtype='object')

# %%
parties.columns
# Out:
# Index(['OBJECTID', 'CASE_ID', 'PARTY_NUMBER', 'PARTY_TYPE', 'AT_FAULT',
#        'PARTY_SEX', 'PARTY_AGE', 'PARTY_SOBRIETY', 'PARTY_DRUG_PHYSICAL',
#        'DIR_OF_TRAVEL', 'PARTY_SAFETY_EQUIP_1', 'PARTY_SAFETY_EQUIP_2',
#        'FINAN_RESPONS', 'SP_INFO_1', 'SP_INFO_2', 'SP_INFO_3',
#        'OAF_VIOLATION_CODE', 'OAF_VIOL_CAT', 'OAF_VIOL_SECTION',
#        'OAF_VIOLATION_SUFFIX', 'OAF_1', 'OAF_2', 'PARTY_NUMBER_KILLED',
#        'PARTY_NUMBER_INJURED', 'MOVE_PRE_ACC', 'VEHICLE_YEAR', 'VEHICLE_MAKE',
#        'STWD_VEHICLE_TYPE', 'CHP_VEH_TYPE_TOWING', 'CHP_VEH_TYPE_TOWED',
#        'RACE', 'INATTENTION', 'SPECIAL_INFO_F', 'SPECIAL_INFO_G',
#        'ACCIDENT_YEAR'],
#       dtype='object')

# %%
victims.columns
# Out:
# Index(['OBJECTID', 'CASE_ID', 'PARTY_NUMBER', 'VICTIM_ROLE', 'VICTIM_SEX',
#        'VICTIM_AGE', 'VICTIM_DEGREE_OF_INJURY', 'VICTIM_SEATING_POSITION',
#        'VICTIM_SAFETY_EQUIP_1', 'VICTIM_SAFETY_EQUIP_2', 'VICTIM_EJECTED',
#        'ACCIDENT_YEAR'],
#       dtype='object')

# %%
# TODO: Join the necessary tables using pd.merge
merged_fatal_victims_2013 = pd.merge(fatal_collisions_2013, fatal_victims_2013, on = 'CASE_ID')
merged_fatal_victims_2013 = pd.merge(merged_fatal_victims_2013, parties, on = ['CASE_ID','PARTY_NUMBER'])

# %%
merged_fatal_victims_2013.shape[0]
# Out:
# 201

# %% [markdown]
# ##### Step 3: Filter out un-necessary columns
# After joining both of the tables, you will notice that we end up with a large number of columns. We don't want to make the policymakers hunt through the data extract for the necessary information; instead, we should be filtering for only the columns that were requested in the extract.

# %%
# TODO: Let's make a list of all the columns we want to keep
keep_cols = ['CASE_ID' , 'COLLISION_DATE' , 'COLLISION_TIME' , 'TYPE_OF_COLLISION' , 
             'ALCOHOL_INVOLVED' , 'VICTIM_AGE' , 'VICTIM_ROLE' , 'DISTANCE', 'PARTY_TYPE']

# TODO: Filter the df for those columns we want
output_fatal_victims_2013 = merged_fatal_victims_2013[keep_cols]

# %%
output_fatal_victims_2013.head()
# Out:
#    CASE_ID            COLLISION_DATE  COLLISION_TIME TYPE_OF_COLLISION  \
# 0  5639079  2013-01-05T00:00:00.000Z            2010                 G
# 1  5639091  2013-01-01T00:00:00.000Z             255                 G
# 2  5639301  2013-01-08T00:00:00.000Z             130                 E
# 3  5639357  2013-01-12T00:00:00.000Z            2210                 E
# 4  5639358  2013-01-10T00:00:00.000Z            1135                 B
#
#   ALCOHOL_INVOLVED  VICTIM_AGE  VICTIM_ROLE  DISTANCE  PARTY_TYPE
# 0                Y          55            3        60         2.0
# 1                Y          23            3       123         2.0
# 2              NaN          44            1         0         1.0
# 3                Y          29            1       100         1.0
# 4              NaN          71            1       163         1.0

# %% [markdown]
# ##### Step 4: Write-out the CSV
# We can write out a CSV using the syntax: `df.to_csv(filepath)`.

# %%
# Before writing out, let's confirm that our current df matches the desired output format,
# using panda's .head() method from before
output_fatal_victims_2013.head()
# Out:
#    CASE_ID            COLLISION_DATE  COLLISION_TIME TYPE_OF_COLLISION  \
# 0  5639079  2013-01-05T00:00:00.000Z            2010                 G
# 1  5639091  2013-01-01T00:00:00.000Z             255                 G
# 2  5639301  2013-01-08T00:00:00.000Z             130                 E
# 3  5639357  2013-01-12T00:00:00.000Z            2210                 E
# 4  5639358  2013-01-10T00:00:00.000Z            1135                 B
#
#   ALCOHOL_INVOLVED  VICTIM_AGE  VICTIM_ROLE  DISTANCE  PARTY_TYPE
# 0                Y          55            3        60         2.0
# 1                Y          23            3       123         2.0
# 2              NaN          44            1         0         1.0
# 3                Y          29            1       100         1.0
# 4              NaN          71            1       163         1.0

# %%
# TODO: Write out the CSV to the data/processed directory
output_fatal_victims_2013.to_csv('output/fatal_victims_2013.csv' , index = False, sep = ',')

# %% [markdown]
# ### Bonus Challenge Exercise
# Prepare the same extract, but this time include the following additional fields:
# - Whether the victim was at fault...
